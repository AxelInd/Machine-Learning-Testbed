# %% [markdown]
# <h1> Speech Rap Signing Classification</h1>
#
# Data source: see my SRS_classifier.ipynb notebook

# %%
import numpy as np
import json
import librosa
import os
import time
import math

# %% [markdown]
# <h2>Data Preperation</h2>
# First we cycle through the data and interpret the music files as MFCCs. MFCCs and their semantic labels are then stored in a .json file.

# %%
"""
@param dataset_path: relative location of the dataset.
@param json_path:
@param n_mfcc: number of mfcc variables to receive
@param hop_length: how far along to move the window
@param num_segments: how many parts to break each file into
"""
def create_mfcc_data(dataset_path, n_mfcc=13, n_fft=2048, hop_length=512, semanticLabelFolderLocation=-2,
              num_segments=5, sample_rate=20000,allLabels={"speech":0,"rap":1,"singing":2},duration = 3):
    #dictionary to store data
    # - mapping: mapp labels to values
    # - labels: target
    data={
        "mapping":[],
        "mfcc":[],
        "labels":[]
    }
    #the length of each sample, we know this for this dataset. Could be calculated dynamically
    
    samples_per_track = sample_rate * duration
    #how many data points we expect to appear in each segment we break our track into
    num_samples_per_segment = int(samples_per_track/num_segments)
    expected_num_mfcc_vectors_per_segment = math.ceil(num_samples_per_segment/ hop_length)
    
    print ("num_samples_per_segment",num_samples_per_segment)
    #loop through all the genres
    #dirpath: folder we are currently in
    #dirnames: all the names of the subfolders
    #filenames: all the filenames
    #i: the count. It MUST be included
    #os.walk returns a generator, that creates a tuple of values: 
    #(current_path, directories in current_path, files in current_path).
    # - each iteration is a different genre
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):
        #ensure we're not yet at the dataset level
        if dirpath is not dataset_path:
            #save the semantic label (the mappings etc)
            #dirpath_components: the individual folder names that make up the full path
            dirpath_components = dirpath.split("\\") #genre/blues => ["genre","blues"]
            semantic_label = dirpath_components[semanticLabelFolderLocation]
            #use the parent directory of a sound file as its label
            data["mapping"].append(semantic_label)
            for f in filenames:
                # load audio file : the path of the file is just its directory path plus its name
                file_path = os.path.join(dirpath,f)
                signal, sr = librosa.load(file_path,sr=sample_rate)
                #process segments to extract MFCC and store data
                for s in range (0, num_segments):
                    start_sample = num_samples_per_segment * s
                    finish_sample = start_sample + num_samples_per_segment
                    #the mfcc for data points between start_sample and finish_sample
                    mfcc = librosa.feature.mfcc(signal[start_sample:finish_sample],sr=sr,n_fft=n_fft,n_mfcc=n_mfcc, hop_length = hop_length)
                    mfcc=mfcc.T
                    #store mfcc for segement if it has the expected length
                    if len(mfcc)==expected_num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        # first iteration was the dataset path
                        correctLabel = allLabels[semantic_label]
                        data["labels"].append(correctLabel)
    return data

# %%
def save_mfcc_data(data,json_path):
    #save what we have created as a jason file
    with open(json_path,"w") as fp:
        json.dump(data,fp,indent=4)

# %%
DATASET_PATH="./data"
JSON_PATH="data.json"
SAMPLE_RATE = 16000
N_MFCC = 13
N_FFT = 2048
HOP_LENGTH=512
NUM_SEGMENTS = 1
ALLLABELS={"speech":0,"rap":1,"singing":2}
DURATION = 3
SEMANTICLABELFOLDERLOCATION=-2

startTime = time.perf_counter()
data=create_mfcc_data(dataset_path=DATASET_PATH, n_mfcc=N_MFCC, n_fft=N_FFT, hop_length=HOP_LENGTH, 
                      semanticLabelFolderLocation=SEMANTICLABELFOLDERLOCATION, num_segments=NUM_SEGMENTS, 
                      sample_rate=SAMPLE_RATE,allLabels=ALLLABELS,duration = DURATION)
save_mfcc_data(data,JSON_PATH)
endTime = time.perf_counter()

print ("Run Complete. Time taken:",endTime-startTime)
# Out:
# num_samples_per_segment 48000
# Run Complete. Time taken: 21.712312700000002

# %% [markdown]
# We use the same MFCC data drawn at 16000 samples per second as we generated for the multi-layer perceptron approach used previously (see SRS_classifier.ipynb).
#
# Data structure:
#
# $x.\texttt{shape}=(\text{num samples},\text{num time intervals}, \text{num MFCC variables})$
#
# $x_i.\texttt{shape} = (\text{num time intervals}, \text{num mfcc variables}))$
#
#
# $y.\texttt{shape}=(\text{num labels})$
#
# $y_i=\text{label}$
#
# where $\text{label} \in \{1,2,3\}$

# %%
#load data from the file
#split data into training and test
"""
load data from a json file with objects "mfcc" and "labels"
@param dataset_path: path to the json file
@return np array of mfcc data, np array of target values
"""
def load_data(dataset_path):
    with open(dataset_path, "r") as fp:
        data = json.load(fp)
        inputs=np.array(data["mfcc"])
        targets=np.array(data["labels"])
        return inputs,targets

# %% [markdown]
# <h3>Load the data</h3>
# Load the data from the jason file and verify that the inputs are of the expected type, and the sample size is as expected, in this case: 480 samples of each label.

# %%
x,y = load_data("data.json")
print ("input shape", x.shape)

unique_elements, counts_elements = np.unique(y, return_counts=True)
print("Frequency of unique values of the targets:")
print(np.asarray((unique_elements, counts_elements)))
# Out:
# input shape (1440, 94, 13)
# Frequency of unique values of the targets:
# [[  0   1   2]
#  [480 480 480]]

# %% [markdown]
# <h3>Create training, validation and test datasets</h3>
# <ul>
#     <li><b>training</b>: used to train the model.</li>
#     <li><b>validation</b>: used to evaluate the model after training.</li>
#     <li><b>test</b>: used to evaluate a model that does well on validation. Ensures that the ML engineer has not been inadvertantly tweaking his model to work on the validation set alone, rather than generalising.</li>
#     </ul>
#
# Here we also add another axis/dimension to our input, giving each training sample a channel depth of 1. (Our CNN will require 3D samples as input). Our labels do not change.

# %%
from sklearn.model_selection import train_test_split
def prepare_datasets(x,y,test_size,validation_size,dataset_path):
    #test set: test on the fully trained model
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=test_size)
    #validation: test on unseen data, but model may end up learning it as we tweak to maximise validation accuracy
    x_train,x_validation,y_train,y_validation=train_test_split(x_train,y_train,test_size=validation_size)
    x_train=x_train[...,np.newaxis]
    x_validation=x_validation[...,np.newaxis]
    x_test=x_test[...,np.newaxis]
    return x_train,x_test,y_train,y_test, x_validation, y_validation

# %% [markdown]
# Data structure:
#
# $x_{train}.\texttt{shape}=(\text{num samples},\text{num time intervals}, \text{num MFCC variables},\text{depth})$
#
# $x_{validate}.\texttt{shape}=(\text{num samples},\text{num time intervals}, \text{num MFCC variables},\text{depth})$
#
# $x_{test}.\texttt{shape}=(\text{num samples},\text{num time intervals}, \text{num MFCC variables},\text{depth})$
#
#
#
# Where $\text{depth}=1$

# %%
x_train,x_test,y_train,y_test, x_validation, y_validation = prepare_datasets(x,y,0.25,0.2, "data.json")

# %%
#(num samples, num intervals, num variables, num channels)
x_train.shape
# Out:
# (864, 94, 13, 1)

# %% [markdown]
# <h2>Models</h2>
# <h3>Model Design 1: Convolutional Neural Network</h3>
# For this model, I opt for a traditional CNN design: three pooled convolutional layers, followed by a single fully connected layer and an output layer, implemented in Tensorflow's Keras environment.

# %%
import tensorflow.keras as keras
"""
Creates a model of three pooled convolutional layers, followed by a single fully connected layer and an output layer.
@param input_shape: the structure of SINGLE value x_i (omits the first dimension of x which is the total number of samples.)
@return uncompiled keras model of the CNN.
"""
def build_model_cnn(input_shape,dropout_rate=0):
    model=keras.Sequential()
    #CONV LAYER 1
    model.add(keras.layers.Conv2D(filters=32,kernel_size=(3,3),activation="relu", input_shape=input_shape))
    model.add(keras.layers.MaxPool2D(pool_size=(3,3),strides=(2,2), padding='same'))
    #Batch normalisation: process that normalises the activations in the current layer for output to the next layer.
    #Speeds up training (faster convergence) and reliability.
    model.add(keras.layers.BatchNormalization())

    #CONV LAYER 2
    model.add(keras.layers.Conv2D(filters=32,kernel_size=(3,3),activation="relu", input_shape=input_shape))
    model.add(keras.layers.MaxPool2D(pool_size=(3,3),strides=(2,2), padding='same'))
    model.add(keras.layers.BatchNormalization())   

    #CONV LAYER 3
    # we shrink the kernal size
    model.add(keras.layers.Conv2D(filters=32,kernel_size=(2,2),activation="relu", input_shape=input_shape))
    model.add(keras.layers.MaxPool2D(pool_size=(2,2),strides=(2,2), padding='same'))
    model.add(keras.layers.BatchNormalization()) 

    #flatten into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64,activation="relu"))
    model.add(keras.layers.Dropout(dropout_rate))  
    
    #output layer
    #a fully connected layer for classification
    NUMBEROFPOSSIBLEOUTPUTS=3
    model.add(keras.layers.Dense(NUMBEROFPOSSIBLEOUTPUTS,activation='softmax'))
    
    return model

# %%
#each sample has the shape (n,130,13,1) <- (num samples,intervals,variables,channels)
input_shape=(x_train.shape[1], x_train.shape[2], x_train.shape[3])
model_cnn = build_model_cnn(input_shape,dropout_rate=0.4)

model_cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 92, 11, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 46, 6, 32)         0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 46, 6, 32)         128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 4, 32)         9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 22, 2, 32)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 22, 2, 32)         128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 1, 32)         4128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 11, 1, 32)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 11, 1, 32)         128
# _________________________________________________________________
# flatten (Flatten)            (None, 352)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                22592
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 36,867
# Trainable params: 36,675
# Non-trainable params: 192
# _________________________________________________________________

# %%
#Adam is a very very effecting sgd variant for deep learning
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
#put all the components together
model_cnn.compile(optimizer=optimizer,
              loss="sparse_categorical_crossentropy", 
              metrics=["accuracy"]
              )

# %% [markdown]
# <h3>Model Design 2: Dense Neural Netowrk</h3>
# For this model, I opt for a traditional MLP design: three hidden convolutional layers and an output layer, implemented in Tensorflow's Keras environment.

# %%
def build_model_dense(input_shape,dropout_rate=0):
    model=keras.Sequential()
    #Flatten Layer
    model.add(keras.layers.Flatten(input_shape=input_shape))
    #Dense Layer 1
    model.add(keras.layers.Dense(512,activation="relu"))
    model.add(keras.layers.Dropout(dropout_rate))
    #Dense Layer 2
    model.add(keras.layers.Dense(256,activation="relu"))
    model.add(keras.layers.Dropout(dropout_rate))              
    #Dense Layer 3
    model.add(keras.layers.Dense(64,activation="relu"))
    model.add(keras.layers.Dropout(dropout_rate))
    #Output Layer
    NUMOUTPUTS=3
    model.add(keras.layers.Dense(NUMOUTPUTS,activation="softmax"))
    return model

# %%
input_shape_dense=(x.shape[1],x.shape[2])
model_dense = build_model_dense(input_shape=input_shape, dropout_rate=0.1)
model_dense.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 1222)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               626176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 774,147
# Trainable params: 774,147
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Adam is a very very effecting sgd variant for deep learning
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
#put all the components together
model_dense.compile(optimizer=optimizer,
              loss="sparse_categorical_crossentropy", 
              metrics=["accuracy"]
              )

# %% [markdown]
# <h3>Model Design 3: Long Short Term Memory</h3>
# For this model, I opt for a two-deep LTSM followed by a dense and output layer.

# %%
"""
Creates a model of two pooled LSTM nodes. These are unwrapped and used to learn predictive state information.
"""
def build_model_lstm(input_shape,dropoutRate=0):
    model=keras.Sequential()
    
    #LSTM Layer 1
    #return_sequences = True: sequence to sequence layer, otherwise sequence to vector
    model.add(keras.layers.LSTM(units=64,activation='tanh',input_shape=input_shape,return_sequences=True))
    #LSTM Layer 2
    model.add(keras.layers.LSTM(units=64,activation='tanh',input_shape=input_shape,return_sequences=False))
    
    #pipe output into a dense layer. No need to flatten because sequence to vector
    model.add(keras.layers.Dense(units=64,activation='relu'))
    model.add(keras.layers.Dropout(dropoutRate))
    
    #output layer
    #a fully connected layer for classification
    NUMBEROFPOSSIBLEOUTPUTS=3
    model.add(keras.layers.Dense(NUMBEROFPOSSIBLEOUTPUTS,activation='softmax'))
    return model

# %%
#each sample has the shape (num samples,intervals,variables,channels=1)
input_shape=(x_train.shape[1], x_train.shape[2])
model_lstm = build_model_lstm(input_shape,dropoutRate=0.4)
model_lstm.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 94, 64)            19968
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 57,347
# Trainable params: 57,347
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Adam is a very very effecting sgd variant for deep learning
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
#put all the components together
model_lstm.compile(optimizer=optimizer,
              loss="sparse_categorical_crossentropy", 
              metrics=["accuracy"]
              )

# %% [markdown]
# <h3>Compiling the model</h3>
# <ul><b>Optimizer</b>: Adam</ul>
# <ul><b>Loss Function</b>: sparse_categorical_crossentropy - a powerful tool for categorization tasks.</ul>
# <ul><b>Metrics</b>: accuracy</ul>

# %% [markdown]
# <h2>Training the Models</h2>
# We fit the model to our training data and validate it against our validation data.

# %%
#stores the progression of several metrics as the model trains.
import time
startTime = time.perf_counter()
history_cnn = model_cnn.fit(x_train,y_train,validation_data=(x_validation,y_validation),epochs=50)
endTime = time.perf_counter()
print ("Run Complete. Time taken:",endTime-startTime)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 0s 14ms/step - loss: 1.4081 - accuracy: 0.4248 - val_loss: 1.7493 - val_accuracy: 0.3333
# Epoch 2/50
# 27/27 [==============================] - 0s 9ms/step - loss: 1.0510 - accuracy: 0.5637 - val_loss: 1.4742 - val_accuracy: 0.3287
# Epoch 3/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.8210 - accuracy: 0.6632 - val_loss: 1.2918 - val_accuracy: 0.3519
# Epoch 4/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.6357 - accuracy: 0.7315 - val_loss: 1.0451 - val_accuracy: 0.4444
# Epoch 5/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.5535 - accuracy: 0.7685 - val_loss: 0.8065 - val_accuracy: 0.5556
# Epoch 6/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.4696 - accuracy: 0.8241 - val_loss: 0.6098 - val_accuracy: 0.7269
# Epoch 7/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.3692 - accuracy: 0.8438 - val_loss: 0.4994 - val_accuracy: 0.8009
# Epoch 8/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.3720 - accuracy: 0.8495 - val_loss: 0.4039 - val_accuracy: 0.8519
# Epoch 9/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.3392 - accuracy: 0.8600 - val_loss: 0.3478 - val_accuracy: 0.8704
# Epoch 10/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.2891 - accuracy: 0.8947 - val_loss: 0.2976 - val_accuracy: 0.8843
# Epoch 11/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.2574 - accuracy: 0.9028 - val_loss: 0.2561 - val_accuracy: 0.9120
# Epoch 12/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.2457 - accuracy: 0.9167 - val_loss: 0.2270 - val_accuracy: 0.9167
# Epoch 13/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.2125 - accuracy: 0.9306 - val_loss: 0.2125 - val_accuracy: 0.9213
# Epoch 14/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.2044 - accuracy: 0.9271 - val_loss: 0.1909 - val_accuracy: 0.9352
# Epoch 15/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1847 - accuracy: 0.9387 - val_loss: 0.1848 - val_accuracy: 0.9444
# Epoch 16/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1643 - accuracy: 0.9468 - val_loss: 0.1815 - val_accuracy: 0.9444
# Epoch 17/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1550 - accuracy: 0.9444 - val_loss: 0.1763 - val_accuracy: 0.9491
# Epoch 18/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1472 - accuracy: 0.9444 - val_loss: 0.1660 - val_accuracy: 0.9491
# Epoch 19/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1486 - accuracy: 0.9537 - val_loss: 0.1586 - val_accuracy: 0.9537
# Epoch 20/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1266 - accuracy: 0.9618 - val_loss: 0.1591 - val_accuracy: 0.9630
# Epoch 21/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1162 - accuracy: 0.9630 - val_loss: 0.1485 - val_accuracy: 0.9630
# Epoch 22/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1202 - accuracy: 0.9583 - val_loss: 0.1446 - val_accuracy: 0.9630
# Epoch 23/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1050 - accuracy: 0.9676 - val_loss: 0.1375 - val_accuracy: 0.9630
# Epoch 24/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0831 - accuracy: 0.9676 - val_loss: 0.1271 - val_accuracy: 0.9630
# Epoch 25/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1141 - accuracy: 0.9618 - val_loss: 0.1180 - val_accuracy: 0.9583
# Epoch 26/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0806 - accuracy: 0.9757 - val_loss: 0.1229 - val_accuracy: 0.9676
# Epoch 27/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0813 - accuracy: 0.9792 - val_loss: 0.1180 - val_accuracy: 0.9630
# Epoch 28/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0820 - accuracy: 0.9745 - val_loss: 0.1121 - val_accuracy: 0.9630
# Epoch 29/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0687 - accuracy: 0.9815 - val_loss: 0.1010 - val_accuracy: 0.9630
# Epoch 30/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0668 - accuracy: 0.9792 - val_loss: 0.0962 - val_accuracy: 0.9630
# Epoch 31/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0560 - accuracy: 0.9826 - val_loss: 0.0943 - val_accuracy: 0.9630
# Epoch 32/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0679 - accuracy: 0.9769 - val_loss: 0.0915 - val_accuracy: 0.9630
# Epoch 33/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0564 - accuracy: 0.9861 - val_loss: 0.0922 - val_accuracy: 0.9630
# Epoch 34/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0497 - accuracy: 0.9907 - val_loss: 0.0953 - val_accuracy: 0.9630
# Epoch 35/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0567 - accuracy: 0.9792 - val_loss: 0.0988 - val_accuracy: 0.9630
# Epoch 36/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0541 - accuracy: 0.9803 - val_loss: 0.0944 - val_accuracy: 0.9722
# Epoch 37/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0423 - accuracy: 0.9931 - val_loss: 0.0862 - val_accuracy: 0.9722
# Epoch 38/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0540 - accuracy: 0.9826 - val_loss: 0.1075 - val_accuracy: 0.9537
# Epoch 39/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0434 - accuracy: 0.9896 - val_loss: 0.0859 - val_accuracy: 0.9722
# Epoch 40/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0476 - accuracy: 0.9861 - val_loss: 0.0837 - val_accuracy: 0.9676
# Epoch 41/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0363 - accuracy: 0.9884 - val_loss: 0.0780 - val_accuracy: 0.9676
# Epoch 42/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0564 - accuracy: 0.9826 - val_loss: 0.0938 - val_accuracy: 0.9630
# Epoch 43/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0387 - accuracy: 0.9907 - val_loss: 0.0832 - val_accuracy: 0.9722
# Epoch 44/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0404 - accuracy: 0.9907 - val_loss: 0.0932 - val_accuracy: 0.9630
# Epoch 45/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0408 - accuracy: 0.9896 - val_loss: 0.0835 - val_accuracy: 0.9676
# Epoch 46/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0292 - accuracy: 0.9942 - val_loss: 0.0809 - val_accuracy: 0.9722
# Epoch 47/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0517 - accuracy: 0.9861 - val_loss: 0.0724 - val_accuracy: 0.9722
# Epoch 48/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0310 - accuracy: 0.9931 - val_loss: 0.0710 - val_accuracy: 0.9722
# Epoch 49/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0254 - accuracy: 0.9977 - val_loss: 0.0591 - val_accuracy: 0.9769
# Epoch 50/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0397 - accuracy: 0.9850 - val_loss: 0.0604 - val_accuracy: 0.9722
# Run Complete. Time taken: 14.078997400000002

# %%
import time
startTime = time.perf_counter()
history_dense = model_dense.fit(x_train, y_train, validation_data=(x_test, y_test),epochs=50, batch_size=32)
endTime = time.perf_counter()
print ("Run Complete. Time taken:",endTime-startTime)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 0s 5ms/step - loss: 31.7312 - accuracy: 0.4444 - val_loss: 5.3675 - val_accuracy: 0.6889
# Epoch 2/50
# 27/27 [==============================] - 0s 2ms/step - loss: 9.0468 - accuracy: 0.6273 - val_loss: 3.2672 - val_accuracy: 0.7472
# Epoch 3/50
# 27/27 [==============================] - 0s 2ms/step - loss: 5.8561 - accuracy: 0.6551 - val_loss: 2.9296 - val_accuracy: 0.7250
# Epoch 4/50
# 27/27 [==============================] - 0s 2ms/step - loss: 5.1587 - accuracy: 0.6759 - val_loss: 2.3120 - val_accuracy: 0.7611
# Epoch 5/50
# 27/27 [==============================] - 0s 2ms/step - loss: 4.2068 - accuracy: 0.6956 - val_loss: 2.2408 - val_accuracy: 0.7417
# Epoch 6/50
# 27/27 [==============================] - 0s 2ms/step - loss: 3.2724 - accuracy: 0.7141 - val_loss: 2.0367 - val_accuracy: 0.7583
# Epoch 7/50
# 27/27 [==============================] - 0s 2ms/step - loss: 2.8303 - accuracy: 0.7245 - val_loss: 1.6082 - val_accuracy: 0.7639
# Epoch 8/50
# 27/27 [==============================] - 0s 2ms/step - loss: 2.5106 - accuracy: 0.7164 - val_loss: 2.0030 - val_accuracy: 0.7444
# Epoch 9/50
# 27/27 [==============================] - 0s 2ms/step - loss: 2.2198 - accuracy: 0.7488 - val_loss: 1.6678 - val_accuracy: 0.7194
# Epoch 10/50
# 27/27 [==============================] - 0s 2ms/step - loss: 2.2305 - accuracy: 0.7465 - val_loss: 1.0864 - val_accuracy: 0.7972
# Epoch 11/50
# 27/27 [==============================] - 0s 2ms/step - loss: 2.0434 - accuracy: 0.7546 - val_loss: 1.2985 - val_accuracy: 0.7750
# Epoch 12/50
# 27/27 [==============================] - 0s 2ms/step - loss: 1.5517 - accuracy: 0.7963 - val_loss: 1.2285 - val_accuracy: 0.7944
# Epoch 13/50
# 27/27 [==============================] - 0s 2ms/step - loss: 1.5628 - accuracy: 0.8044 - val_loss: 1.2553 - val_accuracy: 0.7778
# Epoch 14/50
# 27/27 [==============================] - 0s 2ms/step - loss: 1.5749 - accuracy: 0.7859 - val_loss: 1.0471 - val_accuracy: 0.7778
# Epoch 15/50
# 27/27 [==============================] - 0s 2ms/step - loss: 1.3920 - accuracy: 0.8090 - val_loss: 0.8959 - val_accuracy: 0.8194
# Epoch 16/50
# 27/27 [==============================] - 0s 2ms/step - loss: 1.1365 - accuracy: 0.8252 - val_loss: 0.8552 - val_accuracy: 0.7944
# Epoch 17/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.9510 - accuracy: 0.8148 - val_loss: 0.9572 - val_accuracy: 0.8000
# Epoch 18/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.9294 - accuracy: 0.8403 - val_loss: 0.8809 - val_accuracy: 0.7917
# Epoch 19/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.8320 - accuracy: 0.8426 - val_loss: 0.7323 - val_accuracy: 0.8417
# Epoch 20/50
# 27/27 [==============================] - 0s 2ms/step - loss: 1.0687 - accuracy: 0.8194 - val_loss: 0.7917 - val_accuracy: 0.8333
# Epoch 21/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.8359 - accuracy: 0.8519 - val_loss: 0.8876 - val_accuracy: 0.8278
# Epoch 22/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.8546 - accuracy: 0.8403 - val_loss: 0.8882 - val_accuracy: 0.8083
# Epoch 23/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.7764 - accuracy: 0.8426 - val_loss: 0.8137 - val_accuracy: 0.8139
# Epoch 24/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6268 - accuracy: 0.8542 - val_loss: 0.9007 - val_accuracy: 0.8083
# Epoch 25/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.7008 - accuracy: 0.8704 - val_loss: 0.8008 - val_accuracy: 0.8278
# Epoch 26/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5874 - accuracy: 0.8750 - val_loss: 0.7858 - val_accuracy: 0.8361
# Epoch 27/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5306 - accuracy: 0.8947 - val_loss: 0.7155 - val_accuracy: 0.8583
# Epoch 28/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5606 - accuracy: 0.8854 - val_loss: 0.8223 - val_accuracy: 0.8194
# Epoch 29/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5161 - accuracy: 0.8843 - val_loss: 0.6873 - val_accuracy: 0.8361
# Epoch 30/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5626 - accuracy: 0.8854 - val_loss: 0.7803 - val_accuracy: 0.8417
# Epoch 31/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4609 - accuracy: 0.8947 - val_loss: 0.6588 - val_accuracy: 0.8500
# Epoch 32/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4999 - accuracy: 0.8981 - val_loss: 0.7496 - val_accuracy: 0.8639
# Epoch 33/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4575 - accuracy: 0.9051 - val_loss: 0.5686 - val_accuracy: 0.8694
# Epoch 34/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4761 - accuracy: 0.9039 - val_loss: 0.6514 - val_accuracy: 0.8694
# Epoch 35/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4945 - accuracy: 0.8993 - val_loss: 0.5466 - val_accuracy: 0.8722
# Epoch 36/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4275 - accuracy: 0.9039 - val_loss: 0.5930 - val_accuracy: 0.8639
# Epoch 37/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3049 - accuracy: 0.9155 - val_loss: 0.6007 - val_accuracy: 0.8583
# Epoch 38/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2826 - accuracy: 0.9294 - val_loss: 0.6360 - val_accuracy: 0.8639
# Epoch 39/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3348 - accuracy: 0.9213 - val_loss: 0.8024 - val_accuracy: 0.8556
# Epoch 40/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2935 - accuracy: 0.9340 - val_loss: 0.6296 - val_accuracy: 0.8806
# Epoch 41/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3045 - accuracy: 0.9190 - val_loss: 0.6152 - val_accuracy: 0.8778
# Epoch 42/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3365 - accuracy: 0.9236 - val_loss: 0.7669 - val_accuracy: 0.8694
# Epoch 43/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3199 - accuracy: 0.9144 - val_loss: 0.6285 - val_accuracy: 0.8694
# Epoch 44/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2347 - accuracy: 0.9433 - val_loss: 0.7427 - val_accuracy: 0.8722
# Epoch 45/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2550 - accuracy: 0.9410 - val_loss: 0.6729 - val_accuracy: 0.8750
# Epoch 46/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3050 - accuracy: 0.9282 - val_loss: 0.6198 - val_accuracy: 0.8750
# Epoch 47/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2665 - accuracy: 0.9306 - val_loss: 0.7270 - val_accuracy: 0.8806
# Epoch 48/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1498 - accuracy: 0.9630 - val_loss: 0.8371 - val_accuracy: 0.8778
# Epoch 49/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2023 - accuracy: 0.9537 - val_loss: 0.8295 - val_accuracy: 0.8833
# Epoch 50/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1845 - accuracy: 0.9583 - val_loss: 0.6587 - val_accuracy: 0.8778
# Run Complete. Time taken: 3.366001600000004

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)
x_train, x_validation, y_train, y_validation = train_test_split(x_train, y_train, test_size=0.1)

import time
startTime = time.perf_counter()
history_lstm = model_lstm.fit(x_train,y_train,validation_data=(x_validation,y_validation),epochs=50)
endTime = time.perf_counter()
print ("Run Complete. Time taken:",endTime-startTime)
# Out:
# Epoch 1/50
# 37/37 [==============================] - 2s 42ms/step - loss: 1.0370 - accuracy: 0.4460 - val_loss: 0.9790 - val_accuracy: 0.4923
# Epoch 2/50
# 37/37 [==============================] - 1s 24ms/step - loss: 0.9211 - accuracy: 0.5746 - val_loss: 0.8912 - val_accuracy: 0.5846
# Epoch 3/50
# 37/37 [==============================] - 1s 24ms/step - loss: 0.8280 - accuracy: 0.6595 - val_loss: 0.7906 - val_accuracy: 0.7308
# Epoch 4/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.7447 - accuracy: 0.7093 - val_loss: 0.7216 - val_accuracy: 0.7154
# Epoch 5/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.6938 - accuracy: 0.7264 - val_loss: 0.6639 - val_accuracy: 0.7385
# Epoch 6/50
# 37/37 [==============================] - 1s 24ms/step - loss: 0.6426 - accuracy: 0.7470 - val_loss: 0.6155 - val_accuracy: 0.7308
# Epoch 7/50
# 37/37 [==============================] - 1s 24ms/step - loss: 0.5844 - accuracy: 0.7796 - val_loss: 0.5632 - val_accuracy: 0.7615
# Epoch 8/50
# 37/37 [==============================] - 1s 24ms/step - loss: 0.5286 - accuracy: 0.8079 - val_loss: 0.5057 - val_accuracy: 0.8000
# Epoch 9/50
# 37/37 [==============================] - 1s 24ms/step - loss: 0.4761 - accuracy: 0.8396 - val_loss: 0.4694 - val_accuracy: 0.7923
# Epoch 10/50
# 37/37 [==============================] - 1s 24ms/step - loss: 0.4196 - accuracy: 0.8671 - val_loss: 0.4278 - val_accuracy: 0.8308
# Epoch 11/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.3776 - accuracy: 0.8859 - val_loss: 0.3725 - val_accuracy: 0.8769
# Epoch 12/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.3446 - accuracy: 0.8954 - val_loss: 0.3616 - val_accuracy: 0.8769
# Epoch 13/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.3148 - accuracy: 0.9014 - val_loss: 0.3482 - val_accuracy: 0.8923
# Epoch 14/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.2928 - accuracy: 0.9168 - val_loss: 0.3411 - val_accuracy: 0.8923
# Epoch 15/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.2782 - accuracy: 0.9202 - val_loss: 0.3385 - val_accuracy: 0.8846
# Epoch 16/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.2519 - accuracy: 0.9280 - val_loss: 0.3531 - val_accuracy: 0.8769
# Epoch 17/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.2451 - accuracy: 0.9357 - val_loss: 0.3424 - val_accuracy: 0.8846
# Epoch 18/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.2211 - accuracy: 0.9357 - val_loss: 0.3243 - val_accuracy: 0.8923
# Epoch 19/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.2063 - accuracy: 0.9417 - val_loss: 0.3027 - val_accuracy: 0.8846
# Epoch 20/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.1871 - accuracy: 0.9477 - val_loss: 0.3102 - val_accuracy: 0.9000
# Epoch 21/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.1891 - accuracy: 0.9434 - val_loss: 0.3833 - val_accuracy: 0.8538
# Epoch 22/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.1727 - accuracy: 0.9494 - val_loss: 0.3029 - val_accuracy: 0.8846
# Epoch 23/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.1604 - accuracy: 0.9545 - val_loss: 0.3204 - val_accuracy: 0.8923
# Epoch 24/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.1740 - accuracy: 0.9588 - val_loss: 0.3075 - val_accuracy: 0.9077
# Epoch 25/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.1555 - accuracy: 0.9588 - val_loss: 0.2965 - val_accuracy: 0.8846
# Epoch 26/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.1455 - accuracy: 0.9666 - val_loss: 0.3110 - val_accuracy: 0.9000
# Epoch 27/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.1331 - accuracy: 0.9648 - val_loss: 0.2930 - val_accuracy: 0.9000
# Epoch 28/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.1228 - accuracy: 0.9691 - val_loss: 0.3134 - val_accuracy: 0.8846
# Epoch 29/50
# 37/37 [==============================] - 1s 26ms/step - loss: 0.1208 - accuracy: 0.9700 - val_loss: 0.2930 - val_accuracy: 0.8923
# Epoch 30/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.1156 - accuracy: 0.9674 - val_loss: 0.3425 - val_accuracy: 0.8769
# Epoch 31/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.1060 - accuracy: 0.9743 - val_loss: 0.3003 - val_accuracy: 0.8769
# Epoch 32/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.1017 - accuracy: 0.9768 - val_loss: 0.3265 - val_accuracy: 0.8846
# Epoch 33/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0920 - accuracy: 0.9760 - val_loss: 0.3069 - val_accuracy: 0.9000
# Epoch 34/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0908 - accuracy: 0.9760 - val_loss: 0.3049 - val_accuracy: 0.8923
# Epoch 35/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0861 - accuracy: 0.9811 - val_loss: 0.3036 - val_accuracy: 0.8923
# Epoch 36/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0795 - accuracy: 0.9803 - val_loss: 0.3223 - val_accuracy: 0.8923
# Epoch 37/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0823 - accuracy: 0.9794 - val_loss: 0.2855 - val_accuracy: 0.9077
# Epoch 38/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0819 - accuracy: 0.9794 - val_loss: 0.2990 - val_accuracy: 0.9077
# Epoch 39/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0733 - accuracy: 0.9794 - val_loss: 0.3206 - val_accuracy: 0.8846
# Epoch 40/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0700 - accuracy: 0.9837 - val_loss: 0.3050 - val_accuracy: 0.9000
# Epoch 41/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0690 - accuracy: 0.9794 - val_loss: 0.3540 - val_accuracy: 0.9000
# Epoch 42/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0873 - accuracy: 0.9743 - val_loss: 0.2915 - val_accuracy: 0.9077
# Epoch 43/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0927 - accuracy: 0.9743 - val_loss: 0.3423 - val_accuracy: 0.8923
# Epoch 44/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0718 - accuracy: 0.9811 - val_loss: 0.3095 - val_accuracy: 0.9077
# Epoch 45/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.1034 - accuracy: 0.9666 - val_loss: 0.2244 - val_accuracy: 0.9231
# Epoch 46/50
# 37/37 [==============================] - 1s 26ms/step - loss: 0.0651 - accuracy: 0.9803 - val_loss: 0.2241 - val_accuracy: 0.9077
# Epoch 47/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0530 - accuracy: 0.9863 - val_loss: 0.2157 - val_accuracy: 0.9385
# Epoch 48/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0524 - accuracy: 0.9880 - val_loss: 0.2128 - val_accuracy: 0.9154
# Epoch 49/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0475 - accuracy: 0.9854 - val_loss: 0.2357 - val_accuracy: 0.9000
# Epoch 50/50
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0407 - accuracy: 0.9897 - val_loss: 0.2511 - val_accuracy: 0.9308
# Run Complete. Time taken: 50.272451999999994

# %% [markdown]
# <h2>Evaluating the Trained Model</h2>
# We plot the history of the model across epochs with respect to accuracy and error using.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# It is clear that the model has trained well and consistently achieves accuracy above $97 \%$ on the validation set. It seems to converge to this value after about 20 epochs.

# %%
def plot_accuracy_histories(histories, labels):
    fig,axs = plt.subplots(2,2,figsize=(15,7))
    
    pos=0
    for history in histories:
        axs[0,0].plot(history.history["accuracy"],label="train accuracy {}".format((labels[pos])))
        pos=pos+1
    #loc sets location
    #axs[0,0].legend(loc="lower right")
    axs[0,0].set_title("Training Accuracy Evaluation")
    axs[0,0].set_ylabel("accuracy")
    axs[0,0].set_xlabel("epoch")
    pos=0
    
    for history in histories:
        axs[0,1].plot(history.history["val_accuracy"],label="test accuracy {}".format(labels[pos]))
        #loc sets location
        pos=pos+1
    #axs[0,1].legend(loc="lower right")
    axs[0,1].set_title("Test Accuracy Evaluation")
    axs[0,1].set_ylabel("accuracy")
    axs[0,1].set_xlabel("epoch")   
    pos=0
    
    for history in histories:
        axs[1,0].plot(history.history["loss"],label="train error {}".format(labels[pos]))
        pos=pos+1
    axs[1,0].set_ylabel("error")
    #loc sets location
    #axs[1,0].legend(loc="lower right")
    axs[1,0].set_title("Training Error Evaluation")
    axs[1,0].set_xlabel("epoch")
        
    pos=0
    for history in histories:
        #axs[1,1].plot(history.history["val_loss"],label="test error {}".format(labels[pos]))
        axs[1,1].plot(history.history["val_loss"],label="{}".format(labels[pos]))
        pos=pos+1
    axs[1,1].set_ylabel("error")
    #loc sets location
    axs[1,1].legend(bbox_to_anchor=(0.75, -1),loc="lower right")
    axs[1,1].set_title("Test Error Evaluation")
    axs[1,1].set_xlabel("error")
    axs[1,1].set_xlabel("epoch")
    #just keeps the images from overlapping
    fig.tight_layout() 
    #plt.show()
    plt.savefig('accuracyMeasures.png')

plot_accuracy_histories([history_cnn,history_dense,history_lstm],labels=["Convolutional Neural Network","Dense MLP","Long Short Term Memory"])
