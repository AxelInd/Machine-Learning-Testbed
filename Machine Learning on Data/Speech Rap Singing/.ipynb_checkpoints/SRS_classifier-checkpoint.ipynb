# %% [markdown]
# Data Source: https://www.kaggle.com/andradaolteanu/gtzan-dataset-music-genre-classification
#
# Process Source: https://www.youtube.com/watch?v=szyGiObZymo&list=PL-wATfeyAMNrtbkCNsLcpoAyBBRJZVlnf&index=12

# %%
import os
import librosa
import math
import json
import time

# %%
"""
@param dataset_path: relative location of the dataset.
@param json_path:
@param n_mfcc: number of mfcc variables to receive
@param hop_length: how far along to move the window
@param num_segments: how many parts to break each file into
"""
def create_mfcc_data(dataset_path, n_mfcc=13, n_fft=2048, hop_length=512, semanticLabelFolderLocation=-2,
              num_segments=5, sample_rate=20000,allLabels={"speech":1,"rap":2,"singing":3},duration = 3):
    #dictionary to store data
    # - mapping: mapp labels to values
    # - labels: target
    data={
        "mapping":[],
        "mfcc":[],
        "labels":[]
    }
    #the length of each sample, we know this for this dataset. Could be calculated dynamically
    
    samples_per_track = sample_rate * duration
    #how many data points we expect to appear in each segment we break our track into
    num_samples_per_segment = int(samples_per_track/num_segments)
    expected_num_mfcc_vectors_per_segment = math.ceil(num_samples_per_segment/ hop_length)
    
    print ("num_samples_per_segment",num_samples_per_segment)
    #loop through all the genres
    #dirpath: folder we are currently in
    #dirnames: all the names of the subfolders
    #filenames: all the filenames
    #i: the count. It MUST be included
    #os.walk returns a generator, that creates a tuple of values: 
    #(current_path, directories in current_path, files in current_path).
    # - each iteration is a different genre
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):
        #ensure we're not yet at the dataset level
        if dirpath is not dataset_path:
            #save the semantic label (the mappings etc)
            #dirpath_components: the individual folder names that make up the full path
            dirpath_components = dirpath.split("\\") #genre/blues => ["genre","blues"]
            semantic_label = dirpath_components[semanticLabelFolderLocation]
            #use the parent directory of a sound file as its label
            data["mapping"].append(semantic_label)
            for f in filenames:
                # load audio file : the path of the file is just its directory path plus its name
                file_path = os.path.join(dirpath,f)
                signal, sr = librosa.load(file_path,sr=sample_rate)
                #process segments to extract MFCC and store data
                for s in range (0, num_segments):
                    start_sample = num_samples_per_segment * s
                    finish_sample = start_sample + num_samples_per_segment
                    #the mfcc for data points between start_sample and finish_sample
                    mfcc = librosa.feature.mfcc(signal[start_sample:finish_sample],sr=sr,n_fft=n_fft,n_mfcc=n_mfcc, hop_length = hop_length)
                    mfcc=mfcc.T
                    #store mfcc for segement if it has the expected length
                    if len(mfcc)==expected_num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        # first iteration was the dataset path
                        correctLabel = allLabels[semantic_label]
                        data["labels"].append(correctLabel)
    return data

# %%
def save_mfcc_data(data,json_path):
    #save what we have created as a jason file
    with open(json_path,"w") as fp:
        json.dump(data,fp,indent=4)

# %%
DATASET_PATH="./data"
JSON_PATH="data.json"
SAMPLE_RATE = 16000
N_MFCC = 13
N_FFT = 2048
HOP_LENGTH=512
NUM_SEGMENTS = 1
ALLLABELS={"speech":1,"rap":2,"singing":3}
DURATION = 3
SEMANTICLABELFOLDERLOCATION=-2

startTime = time.perf_counter()
data=create_mfcc_data(dataset_path=DATASET_PATH, n_mfcc=N_MFCC, n_fft=N_FFT, hop_length=HOP_LENGTH, 
                      semanticLabelFolderLocation=SEMANTICLABELFOLDERLOCATION, num_segments=NUM_SEGMENTS, 
                      sample_rate=SAMPLE_RATE,allLabels=ALLLABELS,duration = DURATION)
save_mfcc_data(data,JSON_PATH)
endTime = time.perf_counter()

print ("Run Complete. Time taken:",endTime-startTime)
# Out:
# num_samples_per_segment 48000
# Run Complete. Time taken: 14.465852900000755

# %% [markdown]
# The Network Itself
# Source: https://www.youtube.com/watch?v=_xcFAiufwd0

# %%
import numpy as np
#load data

# split data into training and test

def load_data(dataset_path):
    with open(dataset_path, "r") as fp:
        data = json.load(fp)

        #convert lists into numpy arrays
        # x
        inputs=np.array(data["mfcc"])
        targets=np.array(data["labels"])
        return inputs,targets

# %%
inputs,targets = load_data("data.json")
#inputs.shape[0] num samples
#inputs.shape[1] num time readings
#inputs.shape[2] num values per time interval
print ("input shape", inputs.shape)

#normalise the data. @TODO not sure if this is necessary
mean = np.mean(inputs)
std = np.std(inputs)
inputs=(inputs-mean)/std

unique_elements, counts_elements = np.unique(targets, return_counts=True)
print("Frequency of unique values of the targets:")
print(np.asarray((unique_elements, counts_elements)))
# Out:
# input shape (1440, 94, 13)
# Frequency of unique values of the targets:
# [[  1   2   3]
#  [480 480 480]]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(inputs,targets,test_size=0.1)

print ("x_train",x_train.shape)
print ("x_test",x_test.shape)
print ("y_train",y_train.shape)
print ("y_test",y_test.shape)
# Out:
# x_train (1296, 94, 13)
# x_test (144, 94, 13)
# y_train (1296,)
# y_test (144,)

# %%
from tensorflow import keras
#we will use only a traditional dense mlp for this first test, but CNNs would be far more accurate
#takes multidimensional input and treats it as a vector
#mfcc data is mfcc values taken at itervals. Second dimension is values for that interval.
flattenLayer = keras.layers.Flatten(input_shape=(inputs.shape[1],inputs.shape[2]))
#relu: activation function outputs 0 if net input is less than 0. else outputs h.
#relu is very very effective for training (much faster convergence)
# reduced probability of vanishing gradient: derivative of sigmoid can't be higher than 0,25 so it shrinks and becomes tiny
# relu does not have this problem. So relu allows us to have much deeper networks
#3 hidden layers
denseLayer1 = keras.layers.Dense(512,activation="relu")
denseLayer2 = keras.layers.Dense(256,activation="relu")
denseLayer3 = keras.layers.Dense(64,activation="relu")

#we have 10 categories
#softmax is an activation function that normalised the output (so total is 1)
outputLayer = keras.layers.Dense(10,activation="softmax")
model=keras.Sequential([flattenLayer,denseLayer1,denseLayer2,denseLayer3,outputLayer])

#Adam is a very very effecting sgd variant for deep learning
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
#put all the components together
model.compile(optimizer=optimizer,
              loss="sparse_categorical_crossentropy", 
              metrics=["accuracy"]
              )
#describe our network
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_13 (Flatten)         (None, 1222)              0
# _________________________________________________________________
# dense_52 (Dense)             (None, 512)               626176
# _________________________________________________________________
# dense_53 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_54 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_55 (Dense)             (None, 10)                650
# =================================================================
# Total params: 774,602
# Trainable params: 774,602
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Dealing with overfitting
#
# Source: https://www.youtube.com/watch?v=Gf5DO6br0ts&list=PL-wATfeyAMNrtbkCNsLcpoAyBBRJZVlnf&index=14

# %%
import matplotlib.pyplot as plt
def plot_history(history):
    fig,axs = plt.subplots(2)
    axs[0].plot(history.history["accuracy"],label="train accuracy")
    axs[0].plot(history.history["val_accuracy"],label="test accuracy")
    axs[0].set_ylabel("accuracy")
    #loc sets location
    axs[0].legend(loc="lower right")
    axs[0].set_title("accuracy eval")
    
    axs[1].plot(history.history["loss"],label="train error")
    axs[1].plot(history.history["val_loss"],label="test error")
    axs[1].set_ylabel("error")
    #loc sets location
    axs[1].legend(loc="upper right")
    axs[1].set_title("error eval")
    axs[1].set_xlabel("error")
    axs[1].set_xlabel("epoch")
    
    #just keeps the images from overlapping
    fig.tight_layout() 
    #plt.show()

# %%
#train the network
#batch-size usually 16-128 samples, quick, memory light and fairly accurate
#note the very higha ccuract of the test set and low accuracy of the training set (~98% vs ~58%)
# we are overfitting
#mode.fit returns "A History object. Its History.history attribute is a record of training loss values and metrics
#values at successive epochs, as well as validation loss values and validation metrics values (if applicable)"
history = model.fit(x_train, y_train, validation_data=(x_test, y_test),epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 41/41 [==============================] - 0s 4ms/step - loss: 1.1253 - accuracy: 0.5949 - val_loss: 0.5989 - val_accuracy: 0.7639
# Epoch 2/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.5661 - accuracy: 0.7731 - val_loss: 0.4736 - val_accuracy: 0.8333
# Epoch 3/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.4659 - accuracy: 0.8179 - val_loss: 0.4237 - val_accuracy: 0.8403
# Epoch 4/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.3850 - accuracy: 0.8634 - val_loss: 0.4145 - val_accuracy: 0.8472
# Epoch 5/50
# 41/41 [==============================] - 0s 3ms/step - loss: 0.3431 - accuracy: 0.8696 - val_loss: 0.3680 - val_accuracy: 0.8542
# Epoch 6/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.2758 - accuracy: 0.9035 - val_loss: 0.3221 - val_accuracy: 0.8819
# Epoch 7/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.2300 - accuracy: 0.9313 - val_loss: 0.3120 - val_accuracy: 0.8819
# Epoch 8/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.1992 - accuracy: 0.9437 - val_loss: 0.2910 - val_accuracy: 0.8889
# Epoch 9/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.1684 - accuracy: 0.9522 - val_loss: 0.2937 - val_accuracy: 0.8889
# Epoch 10/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.1390 - accuracy: 0.9722 - val_loss: 0.2886 - val_accuracy: 0.8889
# Epoch 11/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.1106 - accuracy: 0.9776 - val_loss: 0.2487 - val_accuracy: 0.9097
# Epoch 12/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0953 - accuracy: 0.9846 - val_loss: 0.2763 - val_accuracy: 0.8681
# Epoch 13/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0973 - accuracy: 0.9691 - val_loss: 0.2341 - val_accuracy: 0.9375
# Epoch 14/50
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0679 - accuracy: 0.9907 - val_loss: 0.2520 - val_accuracy: 0.9236
# Epoch 15/50
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0492 - accuracy: 0.9954 - val_loss: 0.2437 - val_accuracy: 0.9097
# Epoch 16/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0403 - accuracy: 0.9992 - val_loss: 0.2168 - val_accuracy: 0.9306
# Epoch 17/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0336 - accuracy: 0.9992 - val_loss: 0.2284 - val_accuracy: 0.9236
# Epoch 18/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 0.9992 - val_loss: 0.2475 - val_accuracy: 0.9236
# Epoch 19/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.9375
# Epoch 20/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.2237 - val_accuracy: 0.9236
# Epoch 21/50
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.2320 - val_accuracy: 0.9236
# Epoch 22/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.2278 - val_accuracy: 0.9236
# Epoch 23/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2190 - val_accuracy: 0.9375
# Epoch 24/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.2347 - val_accuracy: 0.9167
# Epoch 25/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2328 - val_accuracy: 0.9375
# Epoch 26/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.2314 - val_accuracy: 0.9306
# Epoch 27/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2338 - val_accuracy: 0.9306
# Epoch 28/50
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9375
# Epoch 29/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.2350 - val_accuracy: 0.9375
# Epoch 30/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2424 - val_accuracy: 0.9306
# Epoch 31/50
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2346 - val_accuracy: 0.9375
# Epoch 32/50
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2318 - val_accuracy: 0.9375
# Epoch 33/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2374 - val_accuracy: 0.9375
# Epoch 34/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.2444 - val_accuracy: 0.9375
# Epoch 35/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2426 - val_accuracy: 0.9444
# Epoch 36/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2403 - val_accuracy: 0.9444
# Epoch 37/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2441 - val_accuracy: 0.9514
# Epoch 38/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2466 - val_accuracy: 0.9444
# Epoch 39/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2436 - val_accuracy: 0.9375
# Epoch 40/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2417 - val_accuracy: 0.9444
# Epoch 41/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2485 - val_accuracy: 0.9375
# Epoch 42/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2441 - val_accuracy: 0.9444
# Epoch 43/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2477 - val_accuracy: 0.9375
# Epoch 44/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2502 - val_accuracy: 0.9375
# Epoch 45/50
# 41/41 [==============================] - 0s 2ms/step - loss: 9.8862e-04 - accuracy: 1.0000 - val_loss: 0.2509 - val_accuracy: 0.9444
# Epoch 46/50
# 41/41 [==============================] - 0s 2ms/step - loss: 9.1248e-04 - accuracy: 1.0000 - val_loss: 0.2518 - val_accuracy: 0.9375
# Epoch 47/50
# 41/41 [==============================] - 0s 2ms/step - loss: 8.3315e-04 - accuracy: 1.0000 - val_loss: 0.2538 - val_accuracy: 0.9375
# Epoch 48/50
# 41/41 [==============================] - 0s 2ms/step - loss: 7.7084e-04 - accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9375
# Epoch 49/50
# 41/41 [==============================] - 0s 3ms/step - loss: 7.2306e-04 - accuracy: 1.0000 - val_loss: 0.2621 - val_accuracy: 0.9375
# Epoch 50/50
# 41/41 [==============================] - 0s 3ms/step - loss: 6.7111e-04 - accuracy: 1.0000 - val_loss: 0.2570 - val_accuracy: 0.9444

# %%
#notice that accuracy stops increasing for the test set pretty soon
# a sure sign of overfitting
plot_history(history)

# %% [markdown]
# <h2>Solutions to overfitting</h2>
# <ul>
#     <li>Simplify your architecture</li>
#     <li> Audio data augmentation: increase number of training samples. Can artificially build training samples (e.g. with pitch shifting, background noise, and time stretching) -- only augment the TRAINING SET</li>
#     <li> Early stopping: stop on conditions other than total num epochs</li>
#     <li> Dropout: randomly (stochastically) drop neurons whilst training. 10% - 50% chance</li>
#     <li> Regularisation: penalty to the error function. Punishes large weights. (L1 and L2 are commong types). L1: Appends absolute error to the standard error function. L2: squares each weights contribution to the standard error. (good for complex learning, but outliers are very bad)</li>
#
# </ul>

# %%
#we will use only a traditional dense mlp for this first test, but CNNs would be far more accurate
#takes multidimensional input and treats it as a vector
#mfcc data is mfcc values taken at itervals. Second dimension is values for that interval.
flattenLayer = keras.layers.Flatten(input_shape=(inputs.shape[1],inputs.shape[2]))
#relu: activation function outputs 0 if net input is less than 0. else outputs h.
#relu is very very effective for training (much faster convergence)
# reduced probability of vanishing gradient: derivative of sigmoid can't be higher than 0,25 so it shrinks and becomes tiny
# relu does not have this problem. So relu allows us to have much deeper networks
#3 hidden layers
#IMPORTANT:: we are also adding REGULARIZER as well as dropout
denseLayer1 = keras.layers.Dense(512,activation="relu", kernel_regularizer=keras.regularizers.l2(0.0001))
#param is dropout probability
dropoutLayer1 = keras.layers.Dropout(0.3)
denseLayer2 = keras.layers.Dense(256,activation="relu",kernel_regularizer=keras.regularizers.l2(0.0001))
dropoutLayer2 = keras.layers.Dropout(0.3)
denseLayer3 = keras.layers.Dense(64,activation="relu",kernel_regularizer=keras.regularizers.l2(0.0001))
dropoutLayer3 = keras.layers.Dropout(0.3)
#we have 10 categories
#softmax is an activation function that normalised the output (so total is 1)
outputLayer = keras.layers.Dense(10,activation="softmax")
model_with_dropout=keras.Sequential([flattenLayer,denseLayer1,dropoutLayer1,denseLayer2,dropoutLayer2,
                                     denseLayer3,dropoutLayer3,outputLayer])

#Adam is a very very effecting sgd variant for deep learning
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
#put all the components together
model_with_dropout.compile(optimizer=optimizer,
              loss="sparse_categorical_crossentropy", 
              metrics=["accuracy"]
              )
#describe our network
model_with_dropout.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_14 (Flatten)         (None, 1222)              0
# _________________________________________________________________
# dense_56 (Dense)             (None, 512)               626176
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_57 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_58 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_59 (Dense)             (None, 10)                650
# =================================================================
# Total params: 774,602
# Trainable params: 774,602
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_with_dropout = model_with_dropout.fit(x_train, y_train, validation_data=(x_test, y_test),epochs=75, batch_size=32)
# Out:
# Epoch 1/150
# 41/41 [==============================] - 1s 5ms/step - loss: 1.7456 - accuracy: 0.3719 - val_loss: 1.0357 - val_accuracy: 0.6597
# Epoch 2/150
# 41/41 [==============================] - 0s 3ms/step - loss: 1.1495 - accuracy: 0.5856 - val_loss: 0.7787 - val_accuracy: 0.7431
# Epoch 3/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.9792 - accuracy: 0.6366 - val_loss: 0.7684 - val_accuracy: 0.7083
# Epoch 4/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8755 - accuracy: 0.6883 - val_loss: 0.6507 - val_accuracy: 0.8125
# Epoch 5/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8183 - accuracy: 0.7130 - val_loss: 0.6328 - val_accuracy: 0.8125
# Epoch 6/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7472 - accuracy: 0.7415 - val_loss: 0.5586 - val_accuracy: 0.8333
# Epoch 7/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7184 - accuracy: 0.7670 - val_loss: 0.5652 - val_accuracy: 0.8403
# Epoch 8/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.6830 - accuracy: 0.7809 - val_loss: 0.5380 - val_accuracy: 0.8264
# Epoch 9/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.6379 - accuracy: 0.7932 - val_loss: 0.5130 - val_accuracy: 0.8611
# Epoch 10/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.5983 - accuracy: 0.8009 - val_loss: 0.4933 - val_accuracy: 0.8611
# Epoch 11/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.5769 - accuracy: 0.8272 - val_loss: 0.4919 - val_accuracy: 0.8542
# Epoch 12/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.5806 - accuracy: 0.8218 - val_loss: 0.4950 - val_accuracy: 0.8403
# Epoch 13/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.5454 - accuracy: 0.8356 - val_loss: 0.4501 - val_accuracy: 0.8611
# Epoch 14/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.5069 - accuracy: 0.8503 - val_loss: 0.4514 - val_accuracy: 0.8681
# Epoch 15/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.4939 - accuracy: 0.8465 - val_loss: 0.4214 - val_accuracy: 0.8750
# Epoch 16/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.4493 - accuracy: 0.8765 - val_loss: 0.4095 - val_accuracy: 0.9028
# Epoch 17/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.4370 - accuracy: 0.8781 - val_loss: 0.4054 - val_accuracy: 0.8958
# Epoch 18/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.4239 - accuracy: 0.8873 - val_loss: 0.3926 - val_accuracy: 0.9028
# Epoch 19/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.3930 - accuracy: 0.8958 - val_loss: 0.3891 - val_accuracy: 0.8958
# Epoch 20/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.3589 - accuracy: 0.9236 - val_loss: 0.3774 - val_accuracy: 0.9028
# Epoch 21/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.3600 - accuracy: 0.9151 - val_loss: 0.3766 - val_accuracy: 0.9097
# Epoch 22/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.3184 - accuracy: 0.9306 - val_loss: 0.3601 - val_accuracy: 0.8889
# Epoch 23/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.3337 - accuracy: 0.9228 - val_loss: 0.3423 - val_accuracy: 0.9167
# Epoch 24/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.2978 - accuracy: 0.9398 - val_loss: 0.3509 - val_accuracy: 0.9028
# Epoch 25/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.2896 - accuracy: 0.9460 - val_loss: 0.3483 - val_accuracy: 0.9097
# Epoch 26/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.2837 - accuracy: 0.9406 - val_loss: 0.3376 - val_accuracy: 0.9028
# Epoch 27/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.2677 - accuracy: 0.9468 - val_loss: 0.3353 - val_accuracy: 0.8958
# Epoch 28/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.2604 - accuracy: 0.9506 - val_loss: 0.3282 - val_accuracy: 0.9028
# Epoch 29/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.2390 - accuracy: 0.9552 - val_loss: 0.3269 - val_accuracy: 0.9236
# Epoch 30/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.2328 - accuracy: 0.9637 - val_loss: 0.3548 - val_accuracy: 0.8958
# Epoch 31/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.2263 - accuracy: 0.9614 - val_loss: 0.3154 - val_accuracy: 0.9167
# Epoch 32/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.2047 - accuracy: 0.9722 - val_loss: 0.3179 - val_accuracy: 0.9306
# Epoch 33/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.2055 - accuracy: 0.9653 - val_loss: 0.3439 - val_accuracy: 0.9097
# Epoch 34/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1935 - accuracy: 0.9761 - val_loss: 0.3432 - val_accuracy: 0.9097
# Epoch 35/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1805 - accuracy: 0.9776 - val_loss: 0.3030 - val_accuracy: 0.9236
# Epoch 36/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1559 - accuracy: 0.9877 - val_loss: 0.3333 - val_accuracy: 0.9097
# Epoch 37/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1774 - accuracy: 0.9776 - val_loss: 0.3114 - val_accuracy: 0.9375
# Epoch 38/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1620 - accuracy: 0.9838 - val_loss: 0.3085 - val_accuracy: 0.9236
# Epoch 39/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1677 - accuracy: 0.9776 - val_loss: 0.3167 - val_accuracy: 0.9167
# Epoch 40/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1608 - accuracy: 0.9815 - val_loss: 0.3074 - val_accuracy: 0.9236
# Epoch 41/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1418 - accuracy: 0.9915 - val_loss: 0.3288 - val_accuracy: 0.9236
# Epoch 42/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1441 - accuracy: 0.9892 - val_loss: 0.3243 - val_accuracy: 0.9236
# Epoch 43/150
# 41/41 [==============================] - 2s 62ms/step - loss: 0.1436 - accuracy: 0.9884 - val_loss: 0.3362 - val_accuracy: 0.9306
# Epoch 44/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1406 - accuracy: 0.9931 - val_loss: 0.3385 - val_accuracy: 0.9167
# Epoch 45/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1516 - accuracy: 0.9838 - val_loss: 0.3558 - val_accuracy: 0.9097
# Epoch 46/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1385 - accuracy: 0.9923 - val_loss: 0.3276 - val_accuracy: 0.9167
# Epoch 47/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1320 - accuracy: 0.9915 - val_loss: 0.3376 - val_accuracy: 0.9167
# Epoch 48/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1281 - accuracy: 0.9946 - val_loss: 0.3493 - val_accuracy: 0.9306
# Epoch 49/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1337 - accuracy: 0.9907 - val_loss: 0.3310 - val_accuracy: 0.9306
# Epoch 50/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1226 - accuracy: 0.9969 - val_loss: 0.3466 - val_accuracy: 0.9306
# Epoch 51/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1196 - accuracy: 0.9985 - val_loss: 0.3454 - val_accuracy: 0.9236
# Epoch 52/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.9946 - val_loss: 0.3388 - val_accuracy: 0.9375
# Epoch 53/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1153 - accuracy: 0.9977 - val_loss: 0.3361 - val_accuracy: 0.9306
# Epoch 54/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1345 - accuracy: 0.9892 - val_loss: 0.3436 - val_accuracy: 0.9306
# Epoch 55/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1173 - accuracy: 0.9969 - val_loss: 0.3701 - val_accuracy: 0.9306
# Epoch 56/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1200 - accuracy: 0.9969 - val_loss: 0.3614 - val_accuracy: 0.9375
# Epoch 57/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1196 - accuracy: 0.9938 - val_loss: 0.3479 - val_accuracy: 0.9236
# Epoch 58/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1210 - accuracy: 0.9938 - val_loss: 0.3680 - val_accuracy: 0.9167
# Epoch 59/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1201 - accuracy: 0.9954 - val_loss: 0.3759 - val_accuracy: 0.9097
# Epoch 60/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1130 - accuracy: 0.9969 - val_loss: 0.3583 - val_accuracy: 0.9167
# Epoch 61/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1177 - accuracy: 0.9938 - val_loss: 0.3484 - val_accuracy: 0.9306
# Epoch 62/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1085 - accuracy: 0.9977 - val_loss: 0.3380 - val_accuracy: 0.9306
# Epoch 63/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1088 - accuracy: 0.9977 - val_loss: 0.3735 - val_accuracy: 0.9306
# Epoch 64/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1105 - accuracy: 0.9977 - val_loss: 0.3643 - val_accuracy: 0.9236
# Epoch 65/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1088 - accuracy: 0.9985 - val_loss: 0.3571 - val_accuracy: 0.9306
# Epoch 66/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1083 - accuracy: 0.9977 - val_loss: 0.3623 - val_accuracy: 0.9236
# Epoch 67/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1044 - accuracy: 1.0000 - val_loss: 0.3669 - val_accuracy: 0.9306
# Epoch 68/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1117 - accuracy: 0.9961 - val_loss: 0.3939 - val_accuracy: 0.9306
# Epoch 69/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1069 - accuracy: 0.9985 - val_loss: 0.3592 - val_accuracy: 0.9236
# Epoch 70/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1088 - accuracy: 0.9977 - val_loss: 0.3619 - val_accuracy: 0.9306
# Epoch 71/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1023 - accuracy: 0.9992 - val_loss: 0.4245 - val_accuracy: 0.9028
# Epoch 72/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1078 - accuracy: 0.9977 - val_loss: 0.4060 - val_accuracy: 0.9236
# Epoch 73/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1046 - accuracy: 0.9977 - val_loss: 0.4270 - val_accuracy: 0.9306
# Epoch 74/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1055 - accuracy: 0.9977 - val_loss: 0.3985 - val_accuracy: 0.9167
# Epoch 75/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1198 - accuracy: 0.9946 - val_loss: 0.4247 - val_accuracy: 0.9236
# Epoch 76/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1095 - accuracy: 0.9969 - val_loss: 0.4587 - val_accuracy: 0.9028
# Epoch 77/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1093 - accuracy: 0.9961 - val_loss: 0.4310 - val_accuracy: 0.9236
# Epoch 78/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1150 - accuracy: 0.9938 - val_loss: 0.4291 - val_accuracy: 0.9236
# Epoch 79/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1106 - accuracy: 0.9954 - val_loss: 0.3863 - val_accuracy: 0.9236
# Epoch 80/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1134 - accuracy: 0.9961 - val_loss: 0.3869 - val_accuracy: 0.9236
# Epoch 81/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1079 - accuracy: 0.9977 - val_loss: 0.3924 - val_accuracy: 0.9167
# Epoch 82/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1031 - accuracy: 0.9992 - val_loss: 0.4335 - val_accuracy: 0.9236
# Epoch 83/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1019 - accuracy: 1.0000 - val_loss: 0.4089 - val_accuracy: 0.9306
# Epoch 84/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1087 - accuracy: 0.9954 - val_loss: 0.4019 - val_accuracy: 0.9375
# Epoch 85/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1112 - accuracy: 0.9946 - val_loss: 0.3432 - val_accuracy: 0.9375
# Epoch 86/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1037 - accuracy: 0.9985 - val_loss: 0.3296 - val_accuracy: 0.9375
# Epoch 87/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1060 - accuracy: 0.9961 - val_loss: 0.3757 - val_accuracy: 0.9306
# Epoch 88/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1014 - accuracy: 0.9969 - val_loss: 0.3905 - val_accuracy: 0.9306
# Epoch 89/150
# 41/41 [==============================] - 1s 21ms/step - loss: 0.0986 - accuracy: 0.9992 - val_loss: 0.3904 - val_accuracy: 0.9236
# Epoch 90/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0974 - accuracy: 1.0000 - val_loss: 0.3824 - val_accuracy: 0.9306
# Epoch 91/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0970 - accuracy: 1.0000 - val_loss: 0.4077 - val_accuracy: 0.9306
# Epoch 92/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1189 - accuracy: 0.9907 - val_loss: 0.4397 - val_accuracy: 0.9028
# Epoch 93/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1050 - accuracy: 0.9977 - val_loss: 0.3631 - val_accuracy: 0.9167
# Epoch 94/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1031 - accuracy: 0.9961 - val_loss: 0.3996 - val_accuracy: 0.9167
# Epoch 95/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0989 - accuracy: 0.9985 - val_loss: 0.4304 - val_accuracy: 0.9236
# Epoch 96/150
# 41/41 [==============================] - 1s 35ms/step - loss: 0.0976 - accuracy: 0.9992 - val_loss: 0.4141 - val_accuracy: 0.9236
# Epoch 97/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0974 - accuracy: 0.9992 - val_loss: 0.3852 - val_accuracy: 0.9236
# Epoch 98/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0971 - accuracy: 0.9992 - val_loss: 0.4034 - val_accuracy: 0.9236
# Epoch 99/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0948 - accuracy: 1.0000 - val_loss: 0.4015 - val_accuracy: 0.9236
# Epoch 100/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0963 - accuracy: 0.9985 - val_loss: 0.4473 - val_accuracy: 0.9306
# Epoch 101/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0972 - accuracy: 0.9992 - val_loss: 0.4492 - val_accuracy: 0.9167
# Epoch 102/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1116 - accuracy: 0.9923 - val_loss: 0.5323 - val_accuracy: 0.9028
# Epoch 103/150
# 41/41 [==============================] - 1s 37ms/step - loss: 0.1027 - accuracy: 0.9992 - val_loss: 0.4241 - val_accuracy: 0.9375
# Epoch 104/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0992 - accuracy: 0.9985 - val_loss: 0.4143 - val_accuracy: 0.9375
# Epoch 105/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1025 - accuracy: 0.9954 - val_loss: 0.3813 - val_accuracy: 0.9306
# Epoch 106/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0972 - accuracy: 0.9969 - val_loss: 0.3686 - val_accuracy: 0.9236
# Epoch 107/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0988 - accuracy: 0.9992 - val_loss: 0.3806 - val_accuracy: 0.9306
# Epoch 108/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0946 - accuracy: 0.9992 - val_loss: 0.3978 - val_accuracy: 0.9375
# Epoch 109/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0936 - accuracy: 1.0000 - val_loss: 0.4315 - val_accuracy: 0.9236
# Epoch 110/150
# 41/41 [==============================] - 2s 39ms/step - loss: 0.0926 - accuracy: 0.9992 - val_loss: 0.4506 - val_accuracy: 0.9306
# Epoch 111/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0927 - accuracy: 0.9992 - val_loss: 0.5223 - val_accuracy: 0.9167
# Epoch 112/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0968 - accuracy: 0.9977 - val_loss: 0.4774 - val_accuracy: 0.9306
# Epoch 113/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0935 - accuracy: 0.9985 - val_loss: 0.4131 - val_accuracy: 0.9306
# Epoch 114/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0923 - accuracy: 1.0000 - val_loss: 0.5173 - val_accuracy: 0.8958
# Epoch 115/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0920 - accuracy: 1.0000 - val_loss: 0.4466 - val_accuracy: 0.9236
# Epoch 116/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0956 - accuracy: 0.9977 - val_loss: 0.4910 - val_accuracy: 0.9097
# Epoch 117/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0928 - accuracy: 0.9992 - val_loss: 0.5081 - val_accuracy: 0.9236
# Epoch 118/150
# 41/41 [==============================] - 2s 40ms/step - loss: 0.0925 - accuracy: 0.9977 - val_loss: 0.4759 - val_accuracy: 0.9306
# Epoch 119/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0910 - accuracy: 1.0000 - val_loss: 0.4495 - val_accuracy: 0.9236
# Epoch 120/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0939 - accuracy: 0.9977 - val_loss: 0.5208 - val_accuracy: 0.9236
# Epoch 121/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0920 - accuracy: 0.9985 - val_loss: 0.4468 - val_accuracy: 0.9167
# Epoch 122/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0956 - accuracy: 0.9961 - val_loss: 0.4769 - val_accuracy: 0.9236
# Epoch 123/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0993 - accuracy: 0.9954 - val_loss: 0.4314 - val_accuracy: 0.9167
# Epoch 124/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0920 - accuracy: 0.9992 - val_loss: 0.4246 - val_accuracy: 0.9306
# Epoch 125/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0925 - accuracy: 0.9985 - val_loss: 0.4093 - val_accuracy: 0.9306
# Epoch 126/150
# 41/41 [==============================] - 2s 39ms/step - loss: 0.0956 - accuracy: 0.9977 - val_loss: 0.4453 - val_accuracy: 0.9236
# Epoch 127/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1094 - accuracy: 0.9954 - val_loss: 0.4466 - val_accuracy: 0.9236
# Epoch 128/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0923 - accuracy: 0.9985 - val_loss: 0.4321 - val_accuracy: 0.9236
# Epoch 129/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0892 - accuracy: 1.0000 - val_loss: 0.4083 - val_accuracy: 0.9236
# Epoch 130/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0911 - accuracy: 0.9992 - val_loss: 0.4317 - val_accuracy: 0.9306
# Epoch 131/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0896 - accuracy: 0.9992 - val_loss: 0.5199 - val_accuracy: 0.9167
# Epoch 132/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0936 - accuracy: 0.9969 - val_loss: 0.4428 - val_accuracy: 0.9236
# Epoch 133/150
# 41/41 [==============================] - 2s 38ms/step - loss: 0.0915 - accuracy: 0.9977 - val_loss: 0.4975 - val_accuracy: 0.9236
# Epoch 134/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0886 - accuracy: 1.0000 - val_loss: 0.4981 - val_accuracy: 0.9306
# Epoch 135/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0956 - accuracy: 0.9969 - val_loss: 0.6173 - val_accuracy: 0.8958
# Epoch 136/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0892 - accuracy: 0.9992 - val_loss: 0.4321 - val_accuracy: 0.9306
# Epoch 137/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0863 - accuracy: 1.0000 - val_loss: 0.4516 - val_accuracy: 0.9306
# Epoch 138/150
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0889 - accuracy: 0.9977 - val_loss: 0.4816 - val_accuracy: 0.9167
# Epoch 139/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0882 - accuracy: 0.9985 - val_loss: 0.4270 - val_accuracy: 0.9375
# Epoch 140/150
# 41/41 [==============================] - 2s 38ms/step - loss: 0.0918 - accuracy: 0.9977 - val_loss: 0.4901 - val_accuracy: 0.9028
# Epoch 141/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0928 - accuracy: 0.9969 - val_loss: 0.4225 - val_accuracy: 0.9306
# Epoch 142/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0917 - accuracy: 0.9985 - val_loss: 0.4626 - val_accuracy: 0.9306
# Epoch 143/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0863 - accuracy: 0.9992 - val_loss: 0.4937 - val_accuracy: 0.9236
# Epoch 144/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0867 - accuracy: 1.0000 - val_loss: 0.4868 - val_accuracy: 0.9375
# Epoch 145/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0869 - accuracy: 0.9992 - val_loss: 0.5001 - val_accuracy: 0.9306
# Epoch 146/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0861 - accuracy: 0.9985 - val_loss: 0.4690 - val_accuracy: 0.9306
# Epoch 147/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0874 - accuracy: 0.9985 - val_loss: 0.5020 - val_accuracy: 0.9236
# Epoch 148/150
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1110 - accuracy: 0.9915 - val_loss: 0.3985 - val_accuracy: 0.9306
# Epoch 149/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0972 - accuracy: 0.9969 - val_loss: 0.4102 - val_accuracy: 0.9444
# Epoch 150/150
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0863 - accuracy: 0.9992 - val_loss: 0.4134 - val_accuracy: 0.9444

# %%
plot_history(history_with_dropout)

# %% [markdown]
# CNNS:
# fewer parameters than desnse layers, perform better
# underlying assumption: image and audio data are somehow structured
# Relies on two special layers: convolution, pooling
#
# convolution: applies the kernel to an image
#
# shape of kernel determines what features it can extract
#
# Architectural decisions CNN: grid size, stride, num kernels, depth (dimensions of the input)
#
# CNN outputs as many 2ds arrays as the number of kernels for each conv layer
#
# pooling: downsample an image. No parameters. Max pooling just takes the max over its grid and outputs that.
#
# Flatten at the end for the final fully connected layer(s)
#
# For audio data: we can just use the image of a spectrogram as input (treat audio as an image)

# %% [markdown]
# MFCCs for CNNs:
