# %% [markdown]
# Data Source: https://www.kaggle.com/andradaolteanu/gtzan-dataset-music-genre-classification
#
# Process Source: https://www.youtube.com/watch?v=szyGiObZymo&list=PL-wATfeyAMNrtbkCNsLcpoAyBBRJZVlnf&index=12

# %%
import os
import librosa
import math
import json

# %%
"""
@param dataset_path: relative location of the dataset.
@param json_path:
@param n_mfcc: number of mfcc variables to receive
@param hop_length: how far along to move the window
@param num_segments: how many parts to break each file into
"""
def save_mfcc(dataset_path,json_path, n_mfcc=13, n_fft=2048, hop_length=512, num_segments=5, sample_rate=20000):
    #dictionary to store data
    # - mapping: mapp labels to values
    # - labels: target
    data={
        "mapping":[],
        "mfcc":[],
        "labels":[]
    }
    #the length of each sample, we know this for this dataset. Could be calculated dynamically
    DURATION = 3
    samples_per_track = sample_rate * DURATION
    #how many data points we expect to appear in each segment we break our track into
    num_samples_per_segment = int(samples_per_track/num_segments)
    expected_num_mfcc_vectors_per_segment = math.ceil(num_samples_per_segment/ hop_length)
    
    print ("num_samples_per_segment",num_samples_per_segment)
    #loop through all the genres
    #dirpath: folder we are currently in
    #dirnames: all the names of the subfolders
    #filenames: all the filenames
    #i: the count. It MUST be included
    #os.walk returns a generator, that creates a tuple of values: 
    #(current_path, directories in current_path, files in current_path).
    # - each iteration is a different genre
    allLabels={"speech":1,"rap":2,"singing":3}
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):
        #ensure we're not yet at the dataset level
        if dirpath is not dataset_path:
            #save the semantic label (the mappings etc)
            #dirpath_components: the individual folder names that make up the full path
            dirpath_components = dirpath.split("\\") #genre/blues => ["genre","blues"]
            semantic_label = dirpath_components[-2]
            #use the parent directory of a sound file as its label
            data["mapping"].append(semantic_label)
            #print ("\nProcessing", semantic_label)
            for f in filenames:
                # load audio file : the path of the file is just its directory path plus its name
                file_path = os.path.join(dirpath,f)
                signal, sr = librosa.load(file_path,sr=sample_rate)
                #process segments to extract MFCC and store data
                for s in range (0, num_segments):
                    start_sample = num_samples_per_segment * s
                    finish_sample = start_sample + num_samples_per_segment
                    
                    #the mfcc for data points between start_sample and finish_sample
                    mfcc = librosa.feature.mfcc(signal[start_sample:finish_sample],sr=sr,n_fft=n_fft,n_mfcc=n_mfcc, hop_length = hop_length)
                    mfcc=mfcc.T
                    
                    #store mfcc for segement if it has the expected length
                    if len(mfcc)==expected_num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        # first iteration was the dataset path
                        correctLabel = allLabels[semantic_label]
                        print ("correct label is ", correctLabel)
                        #data["labels"].append(i-1)
                        data["labels"].append(correctLabel)
                        print ("appending label",i)
                        print ("{},segment{}".format(file_path,s))
    #save what we ahve created as a jason file
    with open(json_path,"w") as fp:
        json.dump(data,fp,indent=4)

# %%
DATASET_PATH="./data"
JSON_PATH="data.json"
SAMPLE_RATE = 16000
N_MFCC = 13
N_FFT = 2048
HOP_LENGTH=512
NUM_SEGMENTS = 1
import time
startTime = time.perf_counter()
data=save_mfcc(DATASET_PATH,JSON_PATH, N_MFCC, N_FFT, HOP_LENGTH, NUM_SEGMENTS, SAMPLE_RATE)
endTime = time.perf_counter()

print ("Run Complete. Time taken:",endTime-startTime)
# Out:
# num_samples_per_segment 48000
# correct label is  2
# appending label 2
# ./data\rap\sing002\sing002_1.wav,segment0
# correct label is  2
# appending label 2
# ./data\rap\sing002\sing002_2.wav,segment0
# correct label is  2
# appending label 2
# ./data\rap\sing002\sing002_3.wav,segment0
# correct label is  2
# appending label 2
# ./data\rap\sing002\sing002_4.wav,segment0
# correct label is  2
# appending label 2
# ./data\rap\sing002\sing002_5.wav,segment0
# correct label is  2
# appending label 2
# ./data\rap\sing002\sing002_6.wav,segment0
# correct label is  2
# appending label 2
# ./data\rap\sing002\sing002_7.wav,segment0
# correct label is  2
# appending label 3
# ./data\rap\sing006\sing006
wav,segment0
# correct label is  3
# appending label 30
# ./data\singing\sing003\sing003_8.wav,segment0
# correct label is  3
# appending label 30
# ./data\singing\sing003\sing003_9.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_1.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_10.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_11.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_12.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_13.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_14.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_15.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_16.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_17.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_18.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_19.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_2.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_20.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_21.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_22.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_23.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_24.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_25.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_26.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_3.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_4.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_5.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_6.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_7.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_8.wav,segment0
# correct label is  3
# appending label 31
# ./data\singing\sing004\sing004_9.wav,segment0
# correct label is  3
# appending label 32
# ./data\singing\sing007\sing007_1.wav,segment0
# correct label is  3
# appending label 32
# ./data\singing\sing007\sing007_10.wav,segment0
# correct label is  3
# appending label 32
# ./data\singing\sing007\sing007_11.wav,segment0
# correct label is  3
# appending label 32
# ./data\singing\sing007\sing007_12.wav,segment0
# correct label is  3
# appending label 32
# ./data\singing\sing007\sing007_2.wav,segment0
# correct label is  3
# appending label 32
# ./data\singing\sing007\sing007_3.wav,segment0
# correct label is  3
# appending label 32
# ./data\singing\sing007\sing007_4.wav,segment0
# correct label is  3
# appending label 32
# ./data\singing\sing007\sing007_5.wav,segment0
# correct label is  3
# appending label 32
# ./data\singing\sing007\sing007_6.wav,segment0
# correct label is  3
# appending label 32
# ./data\singing\sing007\sing007_7.wav,segment0
# correct label is  3
# appending label 32
# ./data\singing\sing007\sing007_8.wav,segment0
# correct label is  3
# appending label 32
# ./data\singing\sing007\sing007_9.wav,segment0
# correct label is  3
# appending label 33
# ./data\singing\sing008\sing008_1.wav,segment0
# correct label is  3
# appending label 33
# ./data\singing\sing008\sing008_10.wav,segment0
# correct label is  3
# appending label 33
# ./data\singing\sing008\sing008_11.wav,segment0
# correct label is  3
# appending label 33
# ./data\singing\sing008\sing008_12.wav,segment0
# correct label is  3
# appending label 33
# ./data\singing\sing008\sing008_2.wav,segment0
# correct label is  3
# appending label 33
# ./data\singing\sing008\sing008_3.wav,segment0
# correct label is  3
# appending label 33
# ./data\singing\sing008\sing008_4.wav,segment0
# correct label is  3
# appending label 33
# ./data\singing\sing008\sing008_5.wav,segment0
# correct label is  3
# appending label 33
# ./data\singing\sing008\sing008_6.wav,segment0
# correct label is  3
# appending label 33
# ./data\singing\sing008\sing008_7.wav,segment0
# correct label is  3
# appending label 33
# ./data\singing\sing008\sing008_8.wav,segment0
# correct label is  3
# appending label 33
# ./data\singing\sing008\sing008_9.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_1.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_10.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_11.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_12.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_13.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_14.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_15.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_16.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_17.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_18.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_19.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_2.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_20.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_21.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_22.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_3.wav,segment0
# correct label is  3
# appending label 34
# ./data\singing\sing009\sing009_4.wav,segment0
# correct label is  3
# appending label 34
# ...
# appending label 56
# ./data\speech\01e\01eo0314.wav,segment0
# correct label is  1
# appending label 56
# ./data\speech\01e\01eo0315.wav,segment0
# correct label is  1
# appending label 56
# ./data\speech\01e\01eo0316.wav,segment0
# correct label is  1
# appending label 56
# ./data\speech\01e\01eo0317.wav,segment0
# correct label is  1
# appending label 56
# ./data\speech\01e\01eo0318.wav,segment0
# correct label is  1
# appending label 56
# ./data\speech\01e\01eo0319.wav,segment0
# correct label is  1
# appending label 56
# ./data\speech\01e\01eo031a.wav,segment0
# correct label is  1
# appending label 56
# ./data\speech\01e\01eo031b.wav,segment0
# correct label is  1
# appending label 56
# ./data\speech\01e\01eo031c.wav,segment0
# correct label is  1
# appending label 56
# ./data\speech\01e\01eo031d.wav,segment0
# correct label is  1
# appending label 56
# ./data\speech\01e\01eo031e.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc0203.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc0204.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc0205.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc0206.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc0207.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc0208.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc0209.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020a.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020b.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020c.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020d.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020e.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020f.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020g.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020h.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020i.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020l.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020m.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020n.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020o.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020p.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020q.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020r.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020s.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020t.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020u.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020v.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020w.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020x.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020y.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc020z.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc0210.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc0211.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc0212.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc0213.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc0214.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc0215.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc0217.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc0218.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc0219.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc021a.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc021b.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc021c.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc021d.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc021e.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc021f.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fc021g.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0301.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0302.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0303.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0304.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0305.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0306.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0307.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0308.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0309.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030a.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030b.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030c.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030d.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030e.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030f.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030g.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030h.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030i.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030j.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030k.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030l.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030m.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030n.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030o.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030p.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030q.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030r.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030s.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030t.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030u.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030v.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030w.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030x.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030y.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo030z.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0310.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0311.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0312.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0313.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0314.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0315.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0316.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0317.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0318.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo0319.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo031a.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo031b.wav,segment0
# correct label is  1
# appending label 57
# ./data\speech\01f\01fo031c.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0201.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0202.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0203.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0204.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0205.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0206.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0207.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0208.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0209.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020a.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020b.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020c.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020d.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020e.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020f.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020g.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020h.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020i.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020j.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020k.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020l.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020m.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020n.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020o.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020p.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020q.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020s.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020t.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020u.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020v.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020w.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020x.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020y.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc020z.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0210.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0211.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0212.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0213.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0214.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0215.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0216.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0217.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0218.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc0219.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc021a.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc021b.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc021c.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc021d.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01gc021e.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0301.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0302.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0303.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0304.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0305.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0306.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0307.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0308.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0309.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030a.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030b.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030c.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030d.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030e.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030f.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030g.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030h.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030i.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030j.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030k.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030l.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030m.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030n.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030o.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030p.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030q.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030r.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030s.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030t.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030u.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030v.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030w.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030x.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030y.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go030z.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0310.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0311.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0312.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0313.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0314.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0315.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0316.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0317.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0318.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go0319.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go031a.wav,segment0
# correct label is  1
# appending label 58
# ./data\speech\01g\01go031b.wav,segment0
# Run Complete. Time taken: 9.774054699999851

# %% [markdown]
# The Network Itself
# Source: https://www.youtube.com/watch?v=_xcFAiufwd0

# %%
import numpy as np
#load data

# split data into training and test

def load_data(dataset_path):
    with open(dataset_path, "r") as fp:
        data = json.load(fp)

        #convert lists into numpy arrays
        # x
        inputs=np.array(data["mfcc"])
        targets=np.array(data["labels"])
        return inputs,targets

# %%
inputs,targets = load_data("data.json")
#inputs.shape[0] num samples
#inputs.shape[1] num time readings
#inputs.shape[2] num values per time interval
print ("input shape", inputs.shape)

unique_elements, counts_elements = np.unique(targets, return_counts=True)
print("Frequency of unique values of the targets:")
print(np.asarray((unique_elements, counts_elements)))
# Out:
# input shape (1440, 94, 13)
# Frequency of unique values of the targets:
# [[  1   2   3]
#  [480 480 480]]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(inputs,targets,test_size=0.3)

print ("x_train",x_train.shape)
print ("x_test",x_test.shape)
print ("y_train",y_train.shape)
print ("y_test",y_test.shape)
# Out:
# x_train (1008, 94, 13)
# x_test (432, 94, 13)
# y_train (1008,)
# y_test (432,)

# %%
from tensorflow import keras
#we will use only a traditional dense mlp for this first test, but CNNs would be far more accurate
#takes multidimensional input and treats it as a vector
#mfcc data is mfcc values taken at itervals. Second dimension is values for that interval.
flattenLayer = keras.layers.Flatten(input_shape=(inputs.shape[1],inputs.shape[2]))
#relu: activation function outputs 0 if net input is less than 0. else outputs h.
#relu is very very effective for training (much faster convergence)
# reduced probability of vanishing gradient: derivative of sigmoid can't be higher than 0,25 so it shrinks and becomes tiny
# relu does not have this problem. So relu allows us to have much deeper networks
#3 hidden layers
denseLayer1 = keras.layers.Dense(512,activation="relu")
denseLayer2 = keras.layers.Dense(256,activation="relu")
denseLayer3 = keras.layers.Dense(64,activation="relu")

#we have 10 categories
#softmax is an activation function that normalised the output (so total is 1)
outputLayer = keras.layers.Dense(10,activation="softmax")
model=keras.Sequential([flattenLayer,denseLayer1,denseLayer2,denseLayer3,outputLayer])

#Adam is a very very effecting sgd variant for deep learning
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
#put all the components together
model.compile(optimizer=optimizer,
              loss="sparse_categorical_crossentropy", 
              metrics=["accuracy"]
              )
#describe our network
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_8 (Flatten)          (None, 1222)              0
# _________________________________________________________________
# dense_32 (Dense)             (None, 512)               626176
# _________________________________________________________________
# dense_33 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_34 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_35 (Dense)             (None, 10)                650
# =================================================================
# Total params: 774,602
# Trainable params: 774,602
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train the network
#batch-size usually 16-128 samples, quick, memory light and fairly accurate
#note the very higha ccuract of the test set and low accuracy of the training set (~98% vs ~58%)
# we are overfitting
#model.fit(x_train,y_train, validation_data=(x_test,y_test),epochs=50,batch_size=32)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 0s 5ms/step - loss: 20.3967 - accuracy: 0.5327 - val_loss: 6.9395 - val_accuracy: 0.7269
# Epoch 2/50
# 32/32 [==============================] - 0s 3ms/step - loss: 3.6011 - accuracy: 0.7718 - val_loss: 3.5923 - val_accuracy: 0.7847
# Epoch 3/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.7385 - accuracy: 0.8353 - val_loss: 3.6731 - val_accuracy: 0.7917
# Epoch 4/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7546 - accuracy: 0.9038 - val_loss: 2.4746 - val_accuracy: 0.8171
# Epoch 5/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3679 - accuracy: 0.9266 - val_loss: 2.6192 - val_accuracy: 0.8310
# Epoch 6/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1655 - accuracy: 0.9673 - val_loss: 2.1626 - val_accuracy: 0.8495
# Epoch 7/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0768 - accuracy: 0.9712 - val_loss: 2.0379 - val_accuracy: 0.8310
# Epoch 8/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0314 - accuracy: 0.9881 - val_loss: 2.3112 - val_accuracy: 0.8287
# Epoch 9/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 0.9911 - val_loss: 2.0239 - val_accuracy: 0.8333
# Epoch 10/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 2.1192 - val_accuracy: 0.8310
# Epoch 11/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.0748 - val_accuracy: 0.8241
# Epoch 12/50
# 32/32 [==============================] - 0s 3ms/step - loss: 4.6380e-04 - accuracy: 1.0000 - val_loss: 2.0610 - val_accuracy: 0.8218
# Epoch 13/50
# 32/32 [==============================] - 0s 3ms/step - loss: 3.0726e-04 - accuracy: 1.0000 - val_loss: 2.0410 - val_accuracy: 0.8241
# Epoch 14/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.5434e-04 - accuracy: 1.0000 - val_loss: 2.0328 - val_accuracy: 0.8241
# Epoch 15/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.2168e-04 - accuracy: 1.0000 - val_loss: 2.0275 - val_accuracy: 0.8241
# Epoch 16/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.0183e-04 - accuracy: 1.0000 - val_loss: 2.0267 - val_accuracy: 0.8241
# Epoch 17/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.8088e-04 - accuracy: 1.0000 - val_loss: 2.0259 - val_accuracy: 0.8241
# Epoch 18/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.
# Epoch 41/50
# 32/32 [==============================] - 0s 3ms/step - loss: 5.9739e-05 - accuracy: 1.0000 - val_loss: 2.0322 - val_accuracy: 0.8287
# Epoch 42/50
# 32/32 [==============================] - 0s 3ms/step - loss: 5.8029e-05 - accuracy: 1.0000 - val_loss: 2.0326 - val_accuracy: 0.8287
# Epoch 43/50
# 32/32 [==============================] - 0s 3ms/step - loss: 5.6625e-05 - accuracy: 1.0000 - val_loss: 2.0334 - val_accuracy: 0.8287
# Epoch 44/50
# 32/32 [==============================] - 0s 3ms/step - loss: 5.5143e-05 - accuracy: 1.0000 - val_loss: 2.0331 - val_accuracy: 0.8287
# Epoch 45/50
# 32/32 [==============================] - 0s 3ms/step - loss: 5.3226e-05 - accuracy: 1.0000 - val_loss: 2.0334 - val_accuracy: 0.8287
# Epoch 46/50
# 32/32 [==============================] - 0s 3ms/step - loss: 5.2410e-05 - accuracy: 1.0000 - val_loss: 2.0339 - val_accuracy: 0.8287
# Epoch 47/50
# 32/32 [==============================] - 0s 3ms/step - loss: 5.0898e-05 - accuracy: 1.0000 - val_loss: 2.0352 - val_accuracy: 0.8287
# Epoch 48/50
# 32/32 [==============================] - 0s 3ms/step - loss: 4.9402e-05 - accuracy: 1.0000 - val_loss: 2.0328 - val_accuracy: 0.8310
# Epoch 49/50
# 32/32 [==============================] - 0s 3ms/step - loss: 4.8150e-05 - accuracy: 1.0000 - val_loss: 2.0333 - val_accuracy: 0.8287
# Epoch 50/50
# 32/32 [==============================] - 0s 3ms/step - loss: 4.6905e-05 - accuracy: 1.0000 - val_loss: 2.0346 - val_accuracy: 0.8287

# %% [markdown]
# Dealing with overfitting
#
# Source: https://www.youtube.com/watch?v=Gf5DO6br0ts&list=PL-wATfeyAMNrtbkCNsLcpoAyBBRJZVlnf&index=14

# %%
import matplotlib.pyplot as plt
def plot_history(history):
    fig,axs = plt.subplots(2)
    axs[0].plot(history.history["accuracy"],label="train accuracy")
    axs[0].plot(history.history["val_accuracy"],label="test accuracy")
    axs[0].set_ylabel("accuracy")
    #loc sets location
    axs[0].legend(loc="lower right")
    axs[0].set_title("accuracy eval")
    
    axs[1].plot(history.history["loss"],label="train error")
    axs[1].plot(history.history["val_loss"],label="test error")
    axs[1].set_ylabel("error")
    #loc sets location
    axs[1].legend(loc="upper right")
    axs[1].set_title("error eval")
    axs[1].set_xlabel("error")
    axs[1].set_xlabel("epoch")
    
    #just keeps the images from overlapping
    fig.tight_layout() 
    #plt.show()

# %%
#mode.fit returns "A History object. Its History.history attribute is a record of training loss values and metrics
#values at successive epochs, as well as validation loss values and validation metrics values (if applicable)"
history = model.fit(x_train, y_train, validation_data=(x_test, y_test),epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 0s 3ms/step - loss: 4.5792e-05 - accuracy: 1.0000 - val_loss: 2.0349 - val_accuracy: 0.8287
# Epoch 2/50
# 32/32 [==============================] - 0s 3ms/step - loss: 4.4495e-05 - accuracy: 1.0000 - val_loss: 2.0366 - val_accuracy: 0.8287
# Epoch 3/50
# 32/32 [==============================] - 0s 3ms/step - loss: 4.3568e-05 - accuracy: 1.0000 - val_loss: 2.0378 - val_accuracy: 0.8287
# Epoch 4/50
# 32/32 [==============================] - 0s 3ms/step - loss: 4.2708e-05 - accuracy: 1.0000 - val_loss: 2.0367 - val_accuracy: 0.8287
# Epoch 5/50
# 32/32 [==============================] - 0s 3ms/step - loss: 4.1427e-05 - accuracy: 1.0000 - val_loss: 2.0374 - val_accuracy: 0.8287
# Epoch 6/50
# 32/32 [==============================] - 0s 3ms/step - loss: 4.0444e-05 - accuracy: 1.0000 - val_loss: 2.0369 - val_accuracy: 0.8287
# Epoch 7/50
# 32/32 [==============================] - 0s 3ms/step - loss: 3.9570e-05 - accuracy: 1.0000 - val_loss: 2.0349 - val_accuracy: 0.8287
# Epoch 8/50
# 32/32 [==============================] - 0s 3ms/step - loss: 3.8519e-05 - accuracy: 1.0000 - val_loss: 2.0387 - val_accuracy: 0.8287
# Epoch 9/50
# 32/32 [==============================] - 0s 3ms/step - loss: 3.7994e-05 - accuracy: 1.0000 - val_loss: 2.0369 - val_accuracy: 0.8287
# Epoch 10/50
# 32/32 [==============================] - 0s 3ms/step - loss: 3.7063e-05 - accuracy: 1.0000 - val_loss: 2.0371 - val_accuracy: 0.8287
# Epoch 11/50
# 32/32 [==============================] - 0s 3ms/step - loss: 3.6174e-05 - accuracy: 1.0000 - val_loss: 2.0383 - val_accuracy: 0.8287
# Epoch 12/50
# 32/32 [==============================] - 0s 3ms/step - loss: 3.5519e-05 - accuracy: 1.0000 - val_loss: 2.0397 - val_accuracy: 0.8287
# Epoch 13/50
# 32/32 [==============================] - 0s 3ms/step - loss: 3.4636e-05 - accuracy: 1.0000 - val_loss: 2.0394 - val_accuracy: 0.8287
# Epoch 14/50
# 32/32 [==============================] - 0s 3ms/step - loss: 3.3859e-05 - accuracy: 1.0000 - val_loss: 2.0403 - val_accuracy: 0.8287
# Epoch 15/50
# 32/32 [==============================] - 0s 3ms/step - loss: 3.3112e-05 - accuracy: 1.0000 - val_loss: 2.0402 - val_accuracy: 0.8287
# Epoch 16/50
# 32/32 [==============================] - 0s 3ms/step - loss: 3.2449e-05 - accuracy: 1.0000 - val_loss: 2.0427 - val_accuracy: 0.8287
# Epoch 17/50
# 32/32 [==============================] - 0s 3ms/step - loss: 3.1755e-05 - accuracy: 1.0000 - val_loss: 2.0409 - val_accuracy: 0.8287
# Epoch 18/50
# 32/32 [==============================] - 0s 3ms/step - loss: 3.1041e-05 - accuracy: 1.0000 - val_loss: 2.0419 - val_accuracy: 0.8287
# Epoch 19/50
# 32/32 [==============================] - 0s 3ms/step - loss: 3.0432e-05 - accuracy: 1.0000 - val_loss: 2.0418 - val_accuracy: 0.8264
# Epoch 20/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.9922e-05 - accuracy: 1.0000 - val_loss: 2.0403 - val_accuracy: 0.8287
# Epoch 21/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.9144e-05 - accuracy: 1.0000 - val_loss: 2.0420 - val_accuracy: 0.8287
# Epoch 22/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.8602e-05 - accuracy: 1.0000 - val_loss: 2.0426 - val_accuracy: 0.8287
# Epoch 23/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.7969e-05 - accuracy: 1.0000 - val_loss: 2.0409 - val_accuracy: 0.8310
# Epoch 24/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.7443e-05 - accuracy: 1.0000 - val_loss: 2.0416 - val_accuracy: 0.8287
# Epoch 25/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.6921e-05 - accuracy: 1.0000 - val_loss: 2.0432 - val_accuracy: 0.8287
# Epoch 26/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.6320e-05 - accuracy: 1.0000 - val_loss: 2.0436 - val_accuracy: 0.8310
# Epoch 27/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.5861e-05 - accuracy: 1.0000 - val_loss: 2.0451 - val_accuracy: 0.8287
# Epoch 28/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.5390e-05 - accuracy: 1.0000 - val_loss: 2.0450 - val_accuracy: 0.8310
# Epoch 29/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.4820e-05 - accuracy: 1.0000 - val_loss: 2.0441 - val_accuracy: 0.8287
# Epoch 30/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.4361e-05 - accuracy: 1.0000 - val_loss: 2.0442 - val_accuracy: 0.8287
# Epoch 31/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.3959e-05 - accuracy: 1.0000 - val_loss: 2.0453 - val_accuracy: 0.8287
# Epoch 32/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.3444e-05 - accuracy: 1.0000 - val_loss: 2.0447 - val_accuracy: 0.8287
# Epoch 33/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.3029e-05 - accuracy: 1.0000 - val_loss: 2.0459 - val_accuracy: 0.8287
# Epoch 34/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.2715e-05 - accuracy: 1.0000 - val_loss: 2.0460 - val_accuracy: 0.8287
# Epoch 35/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.2284e-05 - accuracy: 1.0000 - val_loss: 2.0461 - val_accuracy: 0.8264
# Epoch 36/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.1798e-05 - accuracy: 1.0000 - val_loss: 2.0482 - val_accuracy: 0.8264
# Epoch 37/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.1486e-05 - accuracy: 1.0000 - val_loss: 2.0473 - val_accuracy: 0.8287
# Epoch 38/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.0992e-05 - accuracy: 1.0000 - val_loss: 2.0459 - val_accuracy: 0.8287
# Epoch 39/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.0664e-05 - accuracy: 1.0000 - val_loss: 2.0474 - val_accuracy: 0.8287
# Epoch 40/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.0446e-05 - accuracy: 1.0000 - val_loss: 2.0479 - val_accuracy: 0.8287
# Epoch 41/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.9942e-05 - accuracy: 1.0000 - val_loss: 2.0479 - val_accuracy: 0.8241
# Epoch 42/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.9611e-05 - accuracy: 1.0000 - val_loss: 2.0472 - val_accuracy: 0.8310
# Epoch 43/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.9319e-05 - accuracy: 1.0000 - val_loss: 2.0489 - val_accuracy: 0.8264
# Epoch 44/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.8924e-05 - accuracy: 1.0000 - val_loss: 2.0491 - val_accuracy: 0.8310
# Epoch 45/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.8511e-05 - accuracy: 1.0000 - val_loss: 2.0485 - val_accuracy: 0.8287
# Epoch 46/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.8242e-05 - accuracy: 1.0000 - val_loss: 2.0481 - val_accuracy: 0.8264
# Epoch 47/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.7895e-05 - accuracy: 1.0000 - val_loss: 2.0488 - val_accuracy: 0.8310
# Epoch 48/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.7587e-05 - accuracy: 1.0000 - val_loss: 2.0507 - val_accuracy: 0.8310
# Epoch 49/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.7319e-05 - accuracy: 1.0000 - val_loss: 2.0507 - val_accuracy: 0.8310
# Epoch 50/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.6966e-05 - accuracy: 1.0000 - val_loss: 2.0497 - val_accuracy: 0.8310

# %%
#notice that accuracy stops increasing for the test set pretty soon
# a sure sign of overfitting
plot_history(history)

# %% [markdown]
# <h2>Solutions to overfitting</h2>
# <ul>
#     <li>Simplify your architecture</li>
#     <li> Audio data augmentation: increase number of training samples. Can artificially build training samples (e.g. with pitch shifting, background noise, and time stretching) -- only augment the TRAINING SET</li>
#     <li> Early stopping: stop on conditions other than total num epochs</li>
#     <li> Dropout: randomly (stochastically) drop neurons whilst training. 10% - 50% chance</li>
#     <li> Regularisation: penalty to the error function. Punishes large weights. (L1 and L2 are commong types). L1: Appends absolute error to the standard error function. L2: squares each weights contribution to the standard error. (good for complex learning, but outliers are very bad)</li>
#
# </ul>

# %%
#we will use only a traditional dense mlp for this first test, but CNNs would be far more accurate
#takes multidimensional input and treats it as a vector
#mfcc data is mfcc values taken at itervals. Second dimension is values for that interval.
flattenLayer = keras.layers.Flatten(input_shape=(inputs.shape[1],inputs.shape[2]))
#relu: activation function outputs 0 if net input is less than 0. else outputs h.
#relu is very very effective for training (much faster convergence)
# reduced probability of vanishing gradient: derivative of sigmoid can't be higher than 0,25 so it shrinks and becomes tiny
# relu does not have this problem. So relu allows us to have much deeper networks
#3 hidden layers
#IMPORTANT:: we are also adding REGULARIZER as well as dropout
denseLayer1 = keras.layers.Dense(512,activation="relu", kernel_regularizer=keras.regularizers.l2(0.0001))
#param is dropout probability
dropoutLayer1 = keras.layers.Dropout(0.3)
denseLayer2 = keras.layers.Dense(256,activation="relu",kernel_regularizer=keras.regularizers.l2(0.0001))
dropoutLayer2 = keras.layers.Dropout(0.3)
denseLayer3 = keras.layers.Dense(64,activation="relu",kernel_regularizer=keras.regularizers.l2(0.0001))
dropoutLayer3 = keras.layers.Dropout(0.3)
#we have 10 categories
#softmax is an activation function that normalised the output (so total is 1)
outputLayer = keras.layers.Dense(10,activation="softmax")
model_with_dropout=keras.Sequential([flattenLayer,denseLayer1,dropoutLayer1,denseLayer2,dropoutLayer2,
                                     denseLayer3,dropoutLayer3,outputLayer])

#Adam is a very very effecting sgd variant for deep learning
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
#put all the components together
model_with_dropout.compile(optimizer=optimizer,
              loss="sparse_categorical_crossentropy", 
              metrics=["accuracy"]
              )
#describe our network
model_with_dropout.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_10 (Flatten)         (None, 1222)              0
# _________________________________________________________________
# dense_40 (Dense)             (None, 512)               626176
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_41 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_42 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_43 (Dense)             (None, 10)                650
# =================================================================
# Total params: 774,602
# Trainable params: 774,602
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_with_dropout = model_with_dropout.fit(x_train, y_train, validation_data=(x_test, y_test),epochs=150, batch_size=32)
# Out:
# Epoch 1/150
#
150
# 32/32 [==============================] - 0s 4ms/step - loss: 1.8048 - accuracy: 0.7361 - val_loss: 0.7689 - val_accuracy: 0.8218
# Epoch 29/150
# 32/32 [==============================] - 0s 4ms/step - loss: 1.6425 - accuracy: 0.7262 - val_loss: 0.8137 - val_accuracy: 0.8102
# Epoch 30/150
# 32/32 [==============================] - 0s 4ms/step - loss: 1.6007 - accuracy: 0.7490 - val_loss: 0.8940 - val_accuracy: 0.8310
# Epoch 31/150
# 32/32 [==============================] - 0s 4ms/step - loss: 1.6253 - accuracy: 0.7391 - val_loss: 0.8003 - val_accuracy: 0.8472
# Epoch 32/150
# 32/32 [==============================] - 0s 4ms/step - loss: 1.4642 - accuracy: 0.7579 - val_loss: 0.7884 - val_accuracy: 0.8194
# Epoch 33/150
# 32/32 [==============================] - 0s 4ms/step - loss: 1.3101 - accuracy: 0.7798 - val_loss: 0.8244 - val_accuracy: 0.8241
# Epoch 34/150
# 32/32 [==============================] - 0s 4ms/step - loss: 1.2463 - accuracy: 0.7718 - val_loss: 0.8270 - val_accuracy: 0.8264
# Epoch 35/150
# 32/32 [==============================] - 0s 4ms/step - loss: 1.2836 - accuracy: 0.7708 - val_loss: 0.8027 - val_accuracy: 0.8310
# Epoch 36/150
# 32/32 [==============================] - 0s 4ms/step - loss: 1.1999 - accuracy: 0.7718 - val_loss: 0.7655 - val_accuracy: 0.8356
# Epoch 37/150
# 32/32 [==============================] - 0s 4ms/step - loss: 1.2149 - accuracy: 0.7718 - val_loss: 0.6975 - val_accuracy: 0.8565
# Epoch 38/150
# 32/32 [==============================] - 0s 4ms/step - loss: 1.1574 - accuracy: 0.7629 - val_loss: 0.6450 - val_accuracy: 0.8519
# Epoch 39/150
# 32/32 [==============================] - 0s 4ms/step - loss: 1.0592 - accuracy: 0.7927 - val_loss: 0.6946 - val_accuracy: 0.8449
# Epoch 40/150
# 32/32 [==============================] - 0s 4ms/step - loss: 1.1052 - accuracy: 0.7897 - val_loss: 0.6985 - val_accuracy: 0.8449
# Epoch 41/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9702 - accuracy: 0.7986 - val_loss: 0.6822 - val_accuracy: 0.8495
# Epoch 42/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.8651 - accuracy: 0.7946 - val_loss: 0.6690 - val_accuracy: 0.8426
# Epoch 43/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9773 - accuracy: 0.8016 - val_loss: 0.6731 - val_accuracy: 0.8426
# Epoch 44/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9635 - accuracy: 0.7966 - val_loss: 0.7373 - val_accuracy: 0.8449
# Epoch 45/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9938 - accuracy: 0.7897 - val_loss: 0.6549 - val_accuracy: 0.8519
# Epoch 46/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.8137 - accuracy: 0.8284 - val_loss: 0.6247 - val_accuracy: 0.8611
# Epoch 47/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9093 - accuracy: 0.8254 - val_loss: 0.6244 - val_accuracy: 0.8657
# Epoch 48/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7728 - accuracy: 0.8323 - val_loss: 0.6526 - val_accuracy: 0.8657
# Epoch 49/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.8853 - accuracy: 0.8194 - val_loss: 0.6369 - val_accuracy: 0.8634
# Epoch 50/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7565 - accuracy: 0.8304 - val_loss: 0.6946 - val_accuracy: 0.8588
# Epoch 51/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7488 - accuracy: 0.8433 - val_loss: 0.6097 - val_accuracy: 0.8634
# Epoch 52/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6500 - accuracy: 0.8423 - val_loss: 0.6170 - val_accuracy: 0.8542
# Epoch 53/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.8046 - accuracy: 0.8234 - val_loss: 0.6445 - val_accuracy: 0.8611
# Epoch 54/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7476 - accuracy: 0.8472 - val_loss: 0.6558 - val_accuracy: 0.8588
# Epoch 55/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6844 - accuracy: 0.8562 - val_loss: 0.6017 - val_accuracy: 0.8565
# Epoch 56/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7794 - accuracy: 0.8313 - val_loss: 0.5809 - val_accuracy: 0.8542
# Epoch 57/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6025 - accuracy: 0.8571 - val_loss: 0.6116 - val_accuracy: 0.8588
# Epoch 58/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7036 - accuracy: 0.8462 - val_loss: 0.6093 - val_accuracy: 0.8542
# Epoch 59/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6617 - accuracy: 0.8542 - val_loss: 0.6402 - val_accuracy: 0.8704
# Epoch 60/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5891 - accuracy: 0.8611 - val_loss: 0.6228 - val_accuracy: 0.8634
# Epoch 61/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7460 - accuracy: 0.8452 - val_loss: 0.6417 - val_accuracy: 0.8681
# Epoch 62/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6262 - accuracy: 0.8631 - val_loss: 0.5873 - val_accuracy: 0.8449
# Epoch 63/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5612 - accuracy: 0.8571 - val_loss: 0.5957 - val_accuracy: 0.8611
# Epoch 64/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5502 - accuracy: 0.8661 - val_loss: 0.6844 - val_accuracy: 0.8472
# Epoch 65/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5625 - accuracy: 0.8710 - val_loss: 0.5894 - val_accuracy: 0.8681
# Epoch 66/150
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5631 - accuracy: 0.8700 - val_loss: 0.6213 - val_accuracy: 0.8727
# Epoch 67/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5736 - accuracy: 0.8631 - val_loss: 0.5947 - val_accuracy: 0.8681
# Epoch 68/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5485 - accuracy: 0.8859 - val_loss: 0.6015 - val_accuracy: 0.8657
# Epoch 69/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4859 - accuracy: 0.8909 - val_loss: 0.6057 - val_accuracy: 0.8611
# Epoch 70/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5268 - accuracy: 0.8879 - val_loss: 0.5841 - val_accuracy: 0.8657
# Epoch 71/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4873 - accuracy: 0.8849 - val_loss: 0.5716 - val_accuracy: 0.8588
# Epoch 72/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5084 - accuracy: 0.8790 - val_loss: 0.5381 - val_accuracy: 0.8657
# Epoch 73/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5154 - accuracy: 0.8690 - val_loss: 0.5627 - val_accuracy: 0.8796
# Epoch 74/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4934 - accuracy: 0.8958 - val_loss: 0.5829 - val_accuracy: 0.8750
# Epoch 75/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4305 - accuracy: 0.9038 - val_loss: 0.6663 - val_accuracy: 0.8681
# Epoch 76/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4713 - accuracy: 0.9048 - val_loss: 0.6877 - val_accuracy: 0.8611
# Epoch 77/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4092 - accuracy: 0.8998 - val_loss: 0.6796 - val_accuracy: 0.8727
# Epoch 78/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4392 - accuracy: 0.9067 - val_loss: 0.7551 - val_accuracy: 0.8657
# Epoch 79/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5111 - accuracy: 0.8909 - val_loss: 0.6302 - val_accuracy: 0.8889
# Epoch 80/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4120 - accuracy: 0.9067 - val_loss: 0.6771 - val_accuracy: 0.8796
# Epoch 81/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3773 - accuracy: 0.9226 - val_loss: 0.6518 - val_accuracy: 0.8819
# Epoch 82/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3970 - accuracy: 0.9107 - val_loss: 0.6811 - val_accuracy: 0.8773
# Epoch 83/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3770 - accuracy: 0.9157 - val_loss: 0.6769 - val_accuracy: 0.8773
# Epoch 84/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3845 - accuracy: 0.9147 - val_loss: 0.6439 - val_accuracy: 0.8796
# Epoch 85/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3386 - accuracy: 0.9286 - val_loss: 0.6270 - val_accuracy: 0.8750
# Epoch 86/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3033 - accuracy: 0.9256 - val_loss: 0.6957 - val_accuracy: 0.8727
# Epoch 87/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3964 - accuracy: 0.9077 - val_loss: 0.6667 - val_accuracy: 0.8681
# Epoch 88/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3624 - accuracy: 0.9167 - val_loss: 0.6339 - val_accuracy: 0.8704
# Epoch 89/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3793 - accuracy: 0.9167 - val_loss: 0.6560 - val_accuracy: 0.8750
# Epoch 90/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3637 - accuracy: 0.9206 - val_loss: 0.6169 - val_accuracy: 0.8773
# Epoch 91/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3525 - accuracy: 0.9226 - val_loss: 0.5819 - val_accuracy: 0.8866
# Epoch 92/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3338 - accuracy: 0.9315 - val_loss: 0.5940 - val_accuracy: 0.8843
# Epoch 93/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3815 - accuracy: 0.9157 - val_loss: 0.5735 - val_accuracy: 0.8773
# Epoch 94/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3111 - accuracy: 0.9306 - val_loss: 0.6194 - val_accuracy: 0.8843
# Epoch 95/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3286 - accuracy: 0.9256 - val_loss: 0.6842 - val_accuracy: 0.8796
# Epoch 96/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3352 - accuracy: 0.9345 - val_loss: 0.7054 - val_accuracy: 0.8657
# Epoch 97/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3389 - accuracy: 0.9196 - val_loss: 0.6108 - val_accuracy: 0.8773
# Epoch 98/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3228 - accuracy: 0.9256 - val_loss: 0.6494 - val_accuracy: 0.8727
# Epoch 99/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3466 - accuracy: 0.9306 - val_loss: 0.6196 - val_accuracy: 0.8750
# Epoch 100/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3291 - accuracy: 0.9296 - val_loss: 0.6791 - val_accuracy: 0.8750
# Epoch 101/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2949 - accuracy: 0.9365 - val_loss: 0.6581 - val_accuracy: 0.8819
# Epoch 102/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2608 - accuracy: 0.9474 - val_loss: 0.7302 - val_accuracy: 0.8773
# Epoch 103/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3015 - accuracy: 0.9405 - val_loss: 0.6617 - val_accuracy: 0.8889
# Epoch 104/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3236 - accuracy: 0.9286 - val_loss: 0.6197 - val_accuracy: 0.8935
# Epoch 105/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3374 - accuracy: 0.9276 - val_loss: 0.6258 - val_accuracy: 0.8889
# Epoch 106/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3095 - accuracy: 0.9435 - val_loss: 0.6753 - val_accuracy: 0.8773
# Epoch 107/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2443 - accuracy: 0.9494 - val_loss: 0.7284 - val_accuracy: 0.8819
# Epoch 108/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2598 - accuracy: 0.9554 - val_loss: 0.6416 - val_accuracy: 0.8866
# Epoch 109/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2338 - accuracy: 0.9603 - val_loss: 0.7160 - val_accuracy: 0.8819
# Epoch 110/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2772 - accuracy: 0.9435 - val_loss: 0.7414 - val_accuracy: 0.8796
# Epoch 111/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3088 - accuracy: 0.9355 - val_loss: 0.6719 - val_accuracy: 0.8796
# Epoch 112/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2656 - accuracy: 0.9395 - val_loss: 0.7020 - val_accuracy: 0.8773
# Epoch 113/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2780 - accuracy: 0.9464 - val_loss: 0.6824 - val_accuracy: 0.8796
# Epoch 114/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2142 - accuracy: 0.9623 - val_loss: 0.6791 - val_accuracy: 0.8981
# Epoch 115/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2495 - accuracy: 0.9623 - val_loss: 0.7736 - val_accuracy: 0.8819
# Epoch 116/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2629 - accuracy: 0.9514 - val_loss: 0.7167 - val_accuracy: 0.8819
# Epoch 117/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2287 - accuracy: 0.9563 - val_loss: 0.7806 - val_accuracy: 0.8843
# Epoch 118/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3050 - accuracy: 0.9484 - val_loss: 0.6746 - val_accuracy: 0.8773
# Epoch 119/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2435 - accuracy: 0.9524 - val_loss: 0.6594 - val_accuracy: 0.8750
# Epoch 120/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2419 - accuracy: 0.9683 - val_loss: 0.7119 - val_accuracy: 0.8889
# Epoch 121/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2674 - accuracy: 0.9554 - val_loss: 0.6498 - val_accuracy: 0.8912
# Epoch 122/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2097 - accuracy: 0.9673 - val_loss: 0.6719 - val_accuracy: 0.8912
# Epoch 123/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2329 - accuracy: 0.9633 - val_loss: 0.6741 - val_accuracy: 0.8912
# Epoch 124/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2114 - accuracy: 0.9643 - val_loss: 0.6571 - val_accuracy: 0.8889
# Epoch 125/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1954 - accuracy: 0.9683 - val_loss: 0.6506 - val_accuracy: 0.8935
# Epoch 126/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2030 - accuracy: 0.9573 - val_loss: 0.6728 - val_accuracy: 0.8866
# Epoch 127/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1853 - accuracy: 0.9712 - val_loss: 0.7748 - val_accuracy: 0.8796
# Epoch 128/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2427 - accuracy: 0.9663 - val_loss: 0.7039 - val_accuracy: 0.8912
# Epoch 129/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2227 - accuracy: 0.9643 - val_loss: 0.6922 - val_accuracy: 0.8796
# Epoch 130/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2092 - accuracy: 0.9613 - val_loss: 0.7289 - val_accuracy: 0.8866
# Epoch 131/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2121 - accuracy: 0.9633 - val_loss: 0.6796 - val_accuracy: 0.8935
# Epoch 132/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1885 - accuracy: 0.9722 - val_loss: 0.7809 - val_accuracy: 0.8866
# Epoch 133/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2100 - accuracy: 0.9633 - val_loss: 0.8638 - val_accuracy: 0.8889
# Epoch 134/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2149 - accuracy: 0.9702 - val_loss: 0.7912 - val_accuracy: 0.8843
# Epoch 135/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1880 - accuracy: 0.9782 - val_loss: 0.7800 - val_accuracy: 0.8866
# Epoch 136/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2034 - accuracy: 0.9673 - val_loss: 0.8003 - val_accuracy: 0.8843
# Epoch 137/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2479 - accuracy: 0.9554 - val_loss: 0.8263 - val_accuracy: 0.8912
# Epoch 138/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2082 - accuracy: 0.9722 - val_loss: 0.9319 - val_accuracy: 0.8727
# Epoch 139/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2044 - accuracy: 0.9742 - val_loss: 0.8142 - val_accuracy: 0.8819
# Epoch 140/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1992 - accuracy: 0.9663 - val_loss: 0.9566 - val_accuracy: 0.8773
# Epoch 141/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2386 - accuracy: 0.9663 - val_loss: 0.8642 - val_accuracy: 0.8796
# Epoch 142/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2006 - accuracy: 0.9692 - val_loss: 0.8811 - val_accuracy: 0.8866
# Epoch 143/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2201 - accuracy: 0.9732 - val_loss: 0.8327 - val_accuracy: 0.8796
# Epoch 144/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2032 - accuracy: 0.9702 - val_loss: 0.6712 - val_accuracy: 0.8843
# Epoch 145/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2203 - accuracy: 0.9673 - val_loss: 0.7701 - val_accuracy: 0.8843
# Epoch 146/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1912 - accuracy: 0.9742 - val_loss: 0.7844 - val_accuracy: 0.8935
# Epoch 147/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2055 - accuracy: 0.9702 - val_loss: 0.9126 - val_accuracy: 0.8773
# Epoch 148/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1846 - accuracy: 0.9732 - val_loss: 0.7963 - val_accuracy: 0.8727
# Epoch 149/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2085 - accuracy: 0.9673 - val_loss: 0.9211 - val_accuracy: 0.8750
# Epoch 150/150
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1707 - accuracy: 0.9782 - val_loss: 0.8420 - val_accuracy: 0.8958

# %%
plot_history(history_with_dropout)

# %% [markdown]
# CNNS:
# fewer parameters than desnse layers, perform better
# underlying assumption: image and audio data are somehow structured
# Relies on two special layers: convolution, pooling
#
# convolution: applies the kernel to an image
#
# shape of kernel determines what features it can extract
#
# Architectural decisions CNN: grid size, stride, num kernels, depth (dimensions of the input)
#
# CNN outputs as many 2ds arrays as the number of kernels for each conv layer
#
# pooling: downsample an image. No parameters. Max pooling just takes the max over its grid and outputs that.
#
# Flatten at the end for the final fully connected layer(s)
#
# For audio data: we can just use the image of a spectrogram as input (treat audio as an image)

# %% [markdown]
# MFCCs for CNNs:
